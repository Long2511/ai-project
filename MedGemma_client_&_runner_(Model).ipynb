# %% [markdown]
# # MedGemma client & runner

# %%
# !pip install -U transformers
# !pip install -U huggingface_hub transformers
# !pip install transformers psutil torch datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.1.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface_hub) (8.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import os
import sys

google_colab = "google.colab" in sys.modules and not os.environ.get("VERTEX_PRODUCT")

if google_colab:
    # Use secret if running in Google Colab
    from google.colab import userdata
    os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
else:
    # Store Hugging Face data under `/content` if running in Colab Enterprise
    if os.environ.get("VERTEX_PRODUCT") == "COLAB_ENTERPRISE":
        os.environ["HF_HOME"] = "/content/hf"
    # Authenticate with Hugging Face
    from huggingface_hub import get_token
    if get_token() is None:
        from huggingface_hub import notebook_login
        notebook_login()

# %%
# !pip install --upgrade --quiet accelerate bitsandbytes transformers qdrant-client fastembed qdrant-client[fastembed]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.6/328.6 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 48.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.8/324.8 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.7 MB/s eta 0:00:00

# %%
from transformers import BitsAndBytesConfig
import torch

model_variant = "4b-it"  # @param ["4b-it", "4b-pt"]
model_id = f"google/medgemma-{model_variant}"

use_quantization = True  # @param {type: "boolean"}


# If running a 27B variant in Google Colab, check if the runtime satisfies
# memory requirements
if "27b" in model_variant and google_colab:
    if not ("A100" in torch.cuda.get_device_name(0) and use_quantization):
        raise ValueError(
            "Runtime has insufficient memory to run a 27B variant. "
            "Please select an A100 GPU and use 4-bit quantization."
        )

model_kwargs = dict(
    torch_dtype=torch.bfloat16,
    device_map="auto",
)

if use_quantization:
    model_kwargs["quantization_config"] = BitsAndBytesConfig(load_in_4bit=True)

# %%
# @title
from dataclasses import dataclass
from functools import lru_cache
from typing import Any, Dict, List, Optional
from pathlib import Path
from qdrant_client import QdrantClient, models

from fastembed import TextEmbedding


@dataclass
class RagSettings:
    qdrant_host: str = os.getenv("QDRANT_HOST", "165.22.56.15")
    qdrant_port: int = int(os.getenv("QDRANT_PORT", 6333))
    qdrant_api_key: str | None = os.getenv("QDRANT_API_KEY")
    qdrant_collection: str = os.getenv("QDRANT_COLLECTION", "case_text_2")
    vector_name: str = os.getenv("QDRANT_VECTOR_NAME", "text")
    embed_model: str = os.getenv("EMBED_MODEL", "qdrant/fastembed-multilingual-v3")
    embed_fallbacks: str = os.getenv("EMBED_MODEL_FALLBACKS", "")
    rag_top_k: int = int(os.getenv("RAG_TOP_K", 4))
    context_prefix: str = os.getenv(
        "RAG_CONTEXT_PREFIX",
        "Use the following reference material when reasoning about the case:",
    )


rag_settings = RagSettings()

# %%
# @title
@lru_cache(maxsize=1)
def get_qdrant_client() -> QdrantClient:
    return QdrantClient(
        host=rag_settings.qdrant_host,
        port=rag_settings.qdrant_port,
        api_key=rag_settings.qdrant_api_key,
        prefer_grpc=False,
        timeout=120.0,
    )


def _candidate_embed_models() -> List[str]:
    env_fallbacks = []
    if rag_settings.embed_fallbacks:
        env_fallbacks = [model.strip() for model in rag_settings.embed_fallbacks.split(",") if model.strip()]
    hardcoded = [
        "qdrant/fastembed-multilingual-v1",
        "qdrant/fastembed-multilingual",
        "BAAI/bge-m3",
        "BAAI/bge-base-en-v1.5",
    ]
    candidates: List[str] = [rag_settings.embed_model, *env_fallbacks, *hardcoded]
    seen: set[str] = set()
    unique_candidates: List[str] = []
    for model_name in candidates:
        if not model_name or model_name in seen:
            continue
        seen.add(model_name)
        unique_candidates.append(model_name)
    return unique_candidates


@lru_cache(maxsize=1)
def get_embedder() -> TextEmbedding:
    errors: List[str] = []
    for model_name in _candidate_embed_models():
        try:
            return TextEmbedding(model_name=model_name)
        except ValueError as exc:
            errors.append(f"{model_name}: {exc}")
        except Exception as exc:
            errors.append(f"{model_name}: {exc}")
    error_msg = "Failed to initialise embedding model. "
    if errors:
        error_msg += "; ".join(errors)
    raise RuntimeError(error_msg)


def embed_query(query: str) -> List[float]:
    embedder = get_embedder()
    vectors = list(embedder.embed([query]))
    if not vectors:
        raise ValueError("Failed to compute embedding for query.")

    base_vector  = vectors[0]
    target_dim = 3072
    base_len = len(base_vector)

    # Lặp lại vector cho đến khi đủ 3072
    repeated_vector = []
    while len(repeated_vector) < target_dim:
        remaining = target_dim - len(repeated_vector)
        repeated_vector.extend(base_vector[:min(remaining, base_len)])

    return repeated_vector[:target_dim]

STRUCTURED_DATA_ROOT = Path("/content/drive/MyDrive/Project-AI/structured-data-json")

def load_structured_json(case_id: str) -> Dict[str, Any]:
    """Load full structured JSON for a case."""
    json_path = STRUCTURED_DATA_ROOT / f"{case_id}.json"
    if not json_path.exists():
        return {}
    try:
        return yaml.safe_load(json_path.read_text(encoding="utf-8"))
    except Exception:
        return {}

def retrieve_references(query: str, top_k: Optional[int] = None) -> List[Dict[str, Any]]:
    top_k = top_k or rag_settings.rag_top_k
    vector = embed_query(query)
    client = get_qdrant_client()

    search_kwargs = {
        "collection_name": rag_settings.qdrant_collection,
        "limit": top_k,
        "with_payload": True,
    }

    try:
         # Sử dụng API đơn giản không dùng NamedVector
        if hasattr(client, 'search'):
            # Cách 1: Dùng search với vector thường
            hits = client.search(
                collection_name=rag_settings.qdrant_collection,
                query_vector=vector,
                limit=top_k,
            )
        elif hasattr(client, 'search_points'):
            # Cách 2: Dùng search_points với vector thường
            result = client.search_points(
                collection_name=rag_settings.qdrant_collection,
                query_vector=vector,
                limit=top_k,
                with_payload=True,
            )
            hits = result.points
        else:
            # Cách 3: Dùng query_points với vector thường
            result = client.query_points(
                collection_name=rag_settings.qdrant_collection,
                query=vector,
                limit=top_k,
                with_payload=True,
            )
            hits = result.points
    except Exception as e:
        print(f"Search error: {e}")
    return [
        {
            "id": hit.id,
            "score": hit.score,
            "payload": hit.payload or {},
        }
        for hit in hits
    ]



def format_references(references: List[Dict[str, Any]]) -> str:
    if not references:
        return ""

    chunks: List[str] = []

    for idx, ref in enumerate(references, start=1):
        payload = ref.get("payload", {})
        case_id = payload.get("case_id")
        score = ref.get("score")

        # 1. Load structured JSON
        case_json = load_structured_json(case_id) if case_id else {}

        # 2. Format JSON thành text
        if case_json:
            fields = []
            for k, v in case_json.items():
                fields.append(f"**{k.replace('_', ' ').title()}**: {v}")
            summary = "\n".join(fields)
        else:
            summary = "No JSON data available."

        # 3. Title
        title = f"Case {case_id}" if case_id else f"Reference {idx}"

        # 4. Prefix with score if available
        if score is not None:
            prefix = f"## {title} (score={score:.3f})\n"
        else:
            prefix = f"## {title}\n"

        chunks.append(prefix + summary)

    return "\n\n".join(chunks)



def gather_rag_context(query: Optional[str] = None, top_k: Optional[int] = None) -> tuple[str, List[Dict[str, Any]]]:
    if not query:
        return "", []
    references = retrieve_references(query, top_k=top_k)
    return format_references(references), references

# %%
# @title
def build_system_content(base_instruction: str, *, context: str | None = None) -> List[Dict[str, str]]:
    content: List[Dict[str, str]] = [{"type": "text", "text": base_instruction}]
    if context:
        content.append(
            {
                "type": "text",
                "text": f"{rag_settings.context_prefix}\n\n{context}",
            }
        )
    return content


def build_user_content(prompt: str, *, image: Any | None = None) -> List[Dict[str, Any]]:
    content: List[Dict[str, Any]] = [{"type": "text", "text": prompt}]
    if image is not None:
        content.append({"type": "image", "image": image})
    return content

# %%
# !pip install transformers psutil torch datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from google.colab import files
from PIL import Image
uploaded = files.upload()  # Upload the image file from local system

# Get the uploaded file name
image_path = next(iter(uploaded))
image = Image.open(image_path)

# %% [markdown]
# #Prompt Template

# %%
# Install required packages
# !pip install pyyaml pytest pytest-snapshot

import yaml
import os
from pathlib import Path

# Create directory structure
Path("prompts/medgemma").mkdir(parents=True, exist_ok=True)
# medgemma_prompt.yaml

# Template 1: General_Explain
general_explain = """
name: "general_explain"
description: "Template for general medical explanations"
system_prompt: |
  You are a medical educator providing explanatory information.
  - Explain medical concepts in accessible language. cite sources from the provided context using markers like [1], [2] at the end of relevant paragraphs.
  - Use analogies and examples when helpful
  - Cite sources for factual information, Provide accurate source citations in [number] format.
  - Ensure all references include clickable URLs
  - Distinguish between established facts and areas of uncertainty

  ### Format your response as:
  - **Question**: {question}
  - **Answer**: [Direct answer to the question, answer with citations format [number] at the end of cited/relevant paragraphs.]
  - **References**: [list all references and Another relevant source at the end, include available URL link, example format: [1] source.[https://example.com](https://example.com)

prompt_template: |
  <start_of_turn>user
  Explain the concept: {question}<end_of_turn>
  """
# Template 2: Clinical Q&A
clinical_qa = """
name: "clinical_qa"
description: "Answer a clinical question strictly using retrieved/attached sources."
system_prompt: |
  You are an expert in {specialty} communicating with {audience}. Read the clinical case and provide the single most likely diagnosis.
  ### Format your response as:
  **Predicted disease:**[Respond with most accurate diagnosis name]
  **Reason:**[Short explanation]

prompt_template: |
  You are diagnosing tropical diseases for a patient:
  Question: {user_prompt}
  Patient age: {age}
  Primary symptoms: {symptoms}
"""
# Template 3: Drug Info

drug_info= """
name: "drug_info"
description: "Summarize drug information grounded in the supplied sources."
system_prompt: |
  You are a pharmacology information specialist providing drug-related information.
  - Provide information only from verified sources, 1. Provide accurate inline citations in [number] format.
  - Include mechanism, indications, dosing, interactions, warnings
  - State if information is incomplete or from limited sources
  - Do not make clinical recommendations beyond documented guidelines


  ### Format your response as:
  -**Mechanism**: [How the drug works at molecular/physiological level]
  -**Approved Indications**: [FDA/regulatory approved uses]
  -**Dosing Guidance**: [Recommended dosing, adjustments, administration]
  -**Contraindications**: [Absolute and relative contraindications]
  -**References**: [list all References at the end]

prompt_template: |
  <start_of_turn>user
    Provide drug information for:{question}<end_of_turn>
"""

# Save all templates
templates = {
    "general_explain.yaml": general_explain,
    "drug_info.yaml": drug_info,
    "clinical_qa.yaml": clinical_qa
}

for filename, content in templates.items():
    with open(f"prompts/medgemma/{filename}", "w") as f:
        f.write(content)
    print(f"Created: prompts/medgemma/{filename}")

print("All templates created successfully!")
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (8.4.2)
# Collecting pytest-snapshot
#   Downloading pytest_snapshot-0.9.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from pytest) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest) (2.19.2)
# Downloading pytest_snapshot-0.9.0-py3-none-any.whl (10 kB)
# Installing collected packages: pytest-snapshot
# Successfully installed pytest-snapshot-0.9.0
# Created: prompts/medgemma/general_explain.yaml
# Created: prompts/medgemma/drug_info.yaml
# Created: prompts/medgemma/clinical_qa.yaml
# All templates created successfully!

# %% [markdown]
# #Medgemma without RAG

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
import time
import warnings
from functools import lru_cache
from typing import Any, Dict, List, Optional
import requests
import torch
from transformers import pipeline
from PIL import Image
from io import BytesIO
from pathlib import Path

# Initialize the MedGemma 4B model with optional quantization
pipe = pipeline(
    "image-text-to-text",
    model="google/medgemma-4b-it",
    dtype=torch.bfloat16,
    device="cuda" if torch.cuda.is_available() else "cpu",
)
# Configure dataset path and inference options
TEST_DATA_ROOT = Path("/content/drive/MyDrive/Data/Test-Data/extracted-data")
USE_RAG = False  # Set True to enable retrieval with the original case text
MAX_CASES = None  # Set to an integer to cap processed cases

KEYWORD_MODEL_DEFAULT = os.getenv("RAG_KEYWORD_MODEL", "google/flan-t5-small")
KEYWORD_PROMPT_DEFAULT = os.getenv(
    "RAG_KEYWORD_PROMPT",
    (
        "Extract up to {max_keywords} concise clinical keywords or short phrases "
        "from the following request. Return only a comma-separated list without numbering.\n"
        "Request: {prompt}"
    ),
)

@lru_cache(maxsize=4)
def get_keyword_extractor(model_id: str = KEYWORD_MODEL_DEFAULT):
    device = 0 if torch.cuda.is_available() else -1
    return pipeline("text2text-generation", model=model_id, device=device)

def extract_keywords_with_llm(
    prompt_text: str,
    *,
    max_keywords: int = 6,
    model_id: Optional[str] = None,
    instruction_template: Optional[str] = None,
    **generate_kwargs: Any,
 ) -> List[str]:
    """Use a small seq2seq model to extract search-oriented keywords."""
    if not prompt_text or not prompt_text.strip():
        return []
    chosen_model = model_id or KEYWORD_MODEL_DEFAULT
    instruction = (
        instruction_template or KEYWORD_PROMPT_DEFAULT
    ).format(
        max_keywords=max_keywords,
        prompt=prompt_text.strip(),
        user_prompt=prompt_text.strip(),
    )
    extractor = get_keyword_extractor(chosen_model)
    response = extractor(
        instruction,
        max_new_tokens=64,
        num_return_sequences=1,
        **generate_kwargs,
    )
    generated = ""
    if response and isinstance(response, list):
        candidate = response[0]
        generated = candidate.get("generated_text") or candidate.get("text") or ""
    raw_tokens = re.split(r"[\n,;]|\band\b", generated)
    seen: set[str] = set()
    keywords: List[str] = []
    for token in raw_tokens:
        cleaned = token.strip("\t :.-\u2022\u2023\uf0b7")
        if not cleaned:
            continue
        lowered = cleaned.lower()
        if lowered in seen:
            continue
        seen.add(lowered)
        keywords.append(cleaned)
        if len(keywords) >= max_keywords:
            break
    return keywords

def render_text_template(
    base_text: Optional[str],
    *,
    template: Optional[str] = None,
    variables: Optional[Dict[str, Any]] = None,
    field_name: str = "prompt",
    defaults: Optional[Dict[str, Any]] = None,
 ) -> str:
    """Render free-form text using a format template when provided."""
    text_value = base_text or ""
    if template:
        template_vars: Dict[str, Any] = {
            "prompt": text_value,
            "user_prompt": text_value,
        }
        if defaults:
            template_vars.update(defaults)
        if variables:
            template_vars.update(variables)
        try:
            rendered = template.format(**template_vars)
        except KeyError as exc:
            missing_key = exc.args[0] if exc.args else "unknown"
            raise ValueError(f"{field_name} template expects variable '{missing_key}'.") from exc
        if rendered.strip():
            return rendered
        if text_value.strip():
            return text_value
        raise ValueError(f"{field_name.title()} template rendered an empty string.")
    if text_value.strip():
        return text_value
    raise ValueError(f"Provide a {field_name} or {field_name} template.")

def load_image(image_url: Optional[str] = None, image_path: Optional[str] = None):
    """Load an image from a URL or disk, returning the PIL image or an error dict."""
    if image_url:
        try:
            response = requests.get(image_url)
            response.raise_for_status()
            image_obj = Image.open(BytesIO(response.content))
            image_obj.verify()  # quick integrity check
            image_obj = Image.open(BytesIO(response.content))  # reopen after verify
            return image_obj
        except Exception as exc:
            return {"error": "Failed to load image", "message": str(exc)}
    if image_path:
        try:
            image_obj = Image.open(image_path)
            image_obj.verify()
            image_obj = Image.open(image_path)
            return image_obj
        except Exception as exc:
            return {"error": "Failed to load image", "message": str(exc)}
    return None

def find_case_images(case_dir: Path) -> list[Path]:
    image_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif', '.webp'}
    image_files = []

    # find in the main folder
    for ext in image_extensions:
        image_files.extend(case_dir.glob(f"*{ext}"))
        image_files.extend(case_dir.glob(f"*{ext.upper()}"))

    # find in 'images' folder (If available)
    images_dir = case_dir / "images"
    if images_dir.exists() and images_dir.is_dir():
        for ext in image_extensions:
            image_files.extend(images_dir.glob(f"*{ext}"))
            image_files.extend(images_dir.glob(f"*{ext.upper()}"))

    return sorted(image_files)


def load_case_images(case_dir: Path) -> list[Image.Image]:
    image_paths = find_case_images(case_dir)
    loaded_images = []

    for img_path in image_paths:
        try:
            image = Image.open(img_path)
            # Verify image integrity
            image.verify()
            # Reopen after verify
            image = Image.open(img_path)
            loaded_images.append(image)
        except Exception as e:
            print(f"Failed to load image {img_path.name}: {e}")
    return loaded_images

def build_system_content(system_instruction: str, context: str = "") -> List[Dict[str, Any]]:
    """Build system content for MedGemma."""
    content = [{"type": "text", "text": system_instruction}]
    if context:
        content.append({"type": "text", "text": f"Context: {context}"})
    return content

def build_user_content(prompt: str, image: Optional[Image.Image] = None) -> List[Dict[str, Any]]:
    """Build user content for MedGemma."""
    content = [{"type": "text", "text": prompt}]
    if image:
        content.append({"type": "image", "image": image})
    return content

def extract_answer_from_response(response) -> str:
    """Extract the answer text from MedGemma's response structure."""
    if not response:
        return "No answer."

    # MedGemma typically returns a list with the generated text
    if isinstance(response, list) and len(response) > 0:
        generated_item = response[0]

        # The structure might vary - try different access patterns
        if isinstance(generated_item, dict) and "generated_text" in generated_item:
            generated_text = generated_item["generated_text"]

            # If generated_text is a list, extract the content from the last message
            if isinstance(generated_text, list):
                # Find the last assistant message
                for msg in reversed(generated_text):
                    if isinstance(msg, dict) and msg.get("role") == "assistant":
                        return msg.get("content", "No content found.")
                # If no assistant message found, return the last content
                last_msg = generated_text[-1]
                if isinstance(last_msg, dict) and "content" in last_msg:
                    return last_msg["content"]

            # If it's a string, return it directly
            elif isinstance(generated_text, str):
                return generated_text

        # Try direct string access
        elif isinstance(generated_item, str):
            return generated_item

    # Fallback: convert to string
    return str(response)

def _extract_predicted_disease(answer: str) -> str:
    if not answer:
        return ""
    match = re.search(r"Predicted disease:\s*(.+)", answer, flags=re.IGNORECASE)
    if match:
        return match.group(1).strip()
    return answer.strip()

def run_medgemma(
    prompt: Optional[str] = None,
    *,
    prompt_template: Optional[str] = None,
    prompt_variables: Optional[Dict[str, Any]] = None,
    image: Optional[Image.Image] = None,
    system_instruction: str = "You are an expert in tropical diseases.",
    system_instruction_template: Optional[str] = None,
    system_instruction_variables: Optional[Dict[str, Any]] = None,
    max_new_tokens: int = 2000,
    temperature: float = 0.0,
    **generate_kwargs: Any,
 ) -> Dict[str, Any]:
    """Generate an answer with MedGemma without RAG context."""
    start_time = time.time()
    output: Dict[str, Any] = {
        "answer": None,
        "latency": None,
        "error": None,
        "resolved_prompt": None,
        "resolved_system_instruction": None,
    }

    # Render final prompt
    final_prompt = render_text_template(
        prompt,
        template=prompt_template,
        variables=prompt_variables,
        field_name="prompt",
    )
    output["resolved_prompt"] = final_prompt

    # Render system instruction
    final_system_instruction = render_text_template(
        system_instruction,
        template=system_instruction_template,
        variables=system_instruction_variables,
        field_name="system instruction",
        defaults={"final_prompt": final_prompt},
    )
    output["resolved_system_instruction"] = final_system_instruction

    # Build messages for MedGemma
    system_content = build_system_content(final_system_instruction)
    user_content = build_user_content(
        final_prompt,
        image=image if isinstance(image, Image.Image) else None,
    )
    messages = [
        {"role": "system", "content": system_content},
        {"role": "user", "content": user_content},
    ]

    try:
        response = pipe(
            messages,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            **generate_kwargs,
        )

        # Extract the answer text properly
        output["model_response"] = response[0]["generated_text"][-1]["content"] if response else "No answer."
        generated = response[0].get("generated_text")
        extracted_anw = extract_answer_from_response(response)
        output["answer"] = generated
        # Extract prediction
        output["predicted"] = _extract_predicted_disease(extracted_anw)

        output["system_content"]=system_content
        output["user_content"]

    except Exception as exc:
        output["error"] = f"Model inference error: {exc}"
    finally:
        output["latency"] = time.time() - start_time

    return output

def _format_chat_like_answer(answer: Any) -> str:
    """Convert chat-style answers into a readable text block."""
    if answer is None:
        return ""
    if isinstance(answer, str):
        return answer
    if not isinstance(answer, list):
        return str(answer)

    formatted_lines: List[str] = []
    for message in answer:
        if not isinstance(message, dict):
            formatted_lines.append(str(message))
            continue
        role = str(message.get("role", "assistant")).strip() or "assistant"
        content = message.get("content")
        segments: List[str] = []
        if isinstance(content, list):
            for chunk in content:
                if not isinstance(chunk, dict):
                    segments.append(str(chunk))
                    continue
                chunk_type = chunk.get("type")
                if chunk_type == "text":
                    text = chunk.get("text")
                    if text:
                        segments.append(str(text))
                elif chunk_type == "image":
                    segments.append("[Image provided]")
        elif content is not None:
            segments.append(str(content))

        body = "\n".join(seg for seg in segments if seg).strip()
        if body:
            header = role.title()
            formatted_lines.append(f"{header}:\n{body}")
    return "\n\n".join(formatted_lines).strip()

def pretty_print_result(result: Dict[str, Any] | List[Dict[str, Any]]) -> None:
    """Utility to display the result in a readable form."""
    # If list of result
    if isinstance(result, list):
        for i, case_result in enumerate(result):
            print(f"\n{'='*50}")
            print(f"Case ID: {case_result.get('case_id', 'Unknown')}")
            print(f"{'='*50}")
            _print_single_result(case_result)
        return

    # single result
    _print_single_result(result)

def _print_single_result(result: Dict[str, Any]) -> None:
    """Print a single case result."""
    if result.get("error"):
        print("Error:", result["error"])
        return
    if result.get("resolved_prompt"):
        print("Prompt (resolved):\n", result["resolved_prompt"])
    answer_text = _format_chat_like_answer(result.get("answer"))
    print("\nAnswer:\n", answer_text)
    print(f"\nLatency: {result.get('latency', 0.0):.2f}s")
    if result.get("predicted"):
        print(f"\nPredicted disease: {result.get('predicted')}")


def derive_prompt_variables(
    *,
    user_prompt: str,
    symptom_limit: int = 12,
    age_model_id: Optional[str] = None,
    symptom_model_id: Optional[str] = None,
 ) -> Dict[str, Any]:
    """Build template variables via the keyword LLM to keep prompts DRY. Missing values fall back to placeholders."""
    if not user_prompt or not user_prompt.strip():
        return {}
    variables: Dict[str, Any] = {}

# CÁCH 1: Dùng regex đơn giản để extract tuổi
    age_match = re.search(r'(\d{1,3})\s*[- ]?\s*(year|years|yr|yo|y/o)[- ]?(old)?', user_prompt.lower())
    if age_match:
        try:
            variables["age"] = int(age_match.group(1))
        except ValueError:
            variables["age"] = "unknown"
    else:
        # CÁCH 2: Fallback dùng LLM nếu regex không work
        age_instruction = (
            "Extract the patient's age from the statement. "
            "Respond with a single number if the age is given, otherwise respond with NONE.\n"
            "Patient statement: {prompt}"
        )
        age_candidates = extract_keywords_with_llm(
            user_prompt,
            max_keywords=1,
            model_id=age_model_id,
            instruction_template=age_instruction,
        )
        for token in age_candidates:
            digit_match = re.search(r"\d{1,3}", token)
            if digit_match:
                try:
                    variables["age"] = int(digit_match.group())
                    break
                except ValueError:
                    continue

    symptom_instruction = (
        "List up to {max_keywords} concise clinical symptoms or findings mentioned by the patient. "
        "Return a comma-separated list without numbering.\n"
        "Patient statement: {prompt}"
    )
    symptoms = extract_keywords_with_llm(
        user_prompt,
        max_keywords=symptom_limit,
        model_id=symptom_model_id,
        instruction_template=symptom_instruction,
    )
    if symptoms:
        variables["symptoms"] = ", ".join(symptoms)
    if "age" not in variables:
        variables["age"] = "unknown"
    if "symptoms" not in variables:
        variables["symptoms"] = "unspecified"
    return variables

def run_diagnosis_testcase(*, use_rag: bool = USE_RAG, max_cases: int | None = MAX_CASES):
    if not TEST_DATA_ROOT.exists():
        raise FileNotFoundError(f"Test data directory not found: {TEST_DATA_ROOT}")

    results: list[dict[str, Any]] = []
    case_counter = 0

    print(f"Scanning for cases in: {TEST_DATA_ROOT}")

    for case_dir in sorted(TEST_DATA_ROOT.iterdir()):
        if max_cases is not None and case_counter >= max_cases:
            break
        if not case_dir.is_dir():
            continue

        query_path = case_dir / "query.txt"
        if not query_path.exists():
            continue

        # Create prompt
        user_prompt = query_path.read_text(encoding="utf-8").strip()
        prompt_variables = derive_prompt_variables(
            user_prompt=user_prompt,
            symptom_limit=12,

        )
        prompt_type = "clinical_qa"
        # print(f"Auto-selected prompt type: {prompt_type}")
        #Load the prompt template
        with open(f'/content/prompts/medgemma/{prompt_type}.yaml', 'r') as file:
            config = yaml.safe_load(file)
        # Format a prompt
        prompt_template = config['prompt_template']
        system_instruction = config['system_prompt']

        # Load images (take 1st image only)
        imgs = load_case_images(case_dir)
        image_url = imgs[0] if imgs else None

        image = globals().get("image", None)
        if image is None and image_url:
            image = load_image(image_url=image_url)


        # Run MedGemma without RAG
        response = run_medgemma(
            prompt=user_prompt,
            prompt_template=prompt_template,
            prompt_variables=prompt_variables,
            image=image if isinstance(image, Image.Image) else None,
            system_instruction_template= system_instruction,
            system_instruction_variables={
                "specialty": "tropical pulmonary diseases",
                "audience": "clinicians",
                "test_id": case_dir.name
            },
        )

        # Read ground truth
        ground_truth_path = case_dir / "ground_truth.txt"
        ground_truth = (
            ground_truth_path.read_text(encoding="utf-8").strip()
            if ground_truth_path.exists()
            else ""
        )

        # Store results
        results.append(
            {
                "case_id": case_dir.name,
                "predicted_disease": response.get("predicted"),
                "model_response":response.get("model_response"),
                "answer": response.get("answer"),
                #"latency": response.get("latency"),
                "ground_truth": ground_truth,
                #"resolved_prompt": response.get("resolved_prompt"),
                #"resolved_system_instruction": response.get("resolved_system_instruction"),
            }
        )

        case_counter += 1

    print(f"\nProcessed {case_counter} cases.")
    return results


## Main
testcase_results = run_diagnosis_testcase()
pretty_print_result(testcase_results)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda
# Scanning for cases in: /content/drive/MyDrive/Data/Test-Data/extracted-data
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processed 33 cases.
#
# ==================================================
# Case ID: 001
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 53-year-old woman presented with fever, cough, and malaise after returning from a visit to Lahore. On examination, her temperature was 38°C and she had a rash on her upper chest. A chest X-ray showed patchy basal consolidation and a full blood count revealed a relative lymphocytosis. Malaria films were negative. Blood cultures were drawn and later grew gram-negative bacilli.
# Patient age: 53
# Primary symptoms: List of symptoms of fever, cough, malaise
#
# Assistant:
# **Predicted disease:** Tuberculosis
# **Reason:** The patient's symptoms (fever, cough, malaise), chest X-ray findings (patchy basal consolidation), and the presence of gram-negative bacilli in the blood culture strongly suggest tuberculosis. While the travel history to Lahore is relevant, it doesn't definitively point to a specific tropical disease. The negative malaria film rules out malaria.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 002
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 26-year-old woman presents one week after returning from a trip to the Gambia. She reports an abrupt onset of shivering, feeling cold, rigors, vomiting, and profuse sweating, accompanied by headache and nausea. On examination, she is pale, has a temperature of 39.5°C, and is tachycardic. The patient reports having taken anti-malarial tablets during her trip but was admitted with a febrile illness.
# Patient age: 26
# Primary symptoms: Symptoms of shivering, vomiting, profuse sweating, accompanied by headache, nausea, accompanied by vomiting
#
# Assistant:
# **Predicted disease:** Dengue fever
# **Reason:** The patient's recent travel to the Gambia, coupled with the acute onset of fever, headache, nausea, vomiting, and profuse sweating, strongly suggests dengue fever. The presence of shivering and rigors is also consistent with this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 003
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 72-year-old man who lives in the south of Spain presented in the UK with a progressive illness characterized by fever, malaise, weight loss, and loss of appetite. On examination, he had temperatures up to 39°C and progressive, marked hepatosplenomegaly. Blood tests revealed pancytopenia, and he did not respond to broad-spectrum antibiotics. A bone marrow examination was negative for malignancy and initial stains for organisms were unrevealing. Four months prior to his illness, he had been on a camping trip in a coastal area of Spain, where he recalls seeing many thin dogs.
# Patient age: 72
# Primary symptoms: hepatosplenomegaly, hepato
#
# Assistant:
# **Predicted disease:** Histoplasmosis
# **Reason:** The patient's presentation of fever, malaise, weight loss, hepatosplenomegaly, pancytopenia, and lack of response to antibiotics, coupled with a history of camping in a coastal area of Spain where he saw many thin dogs, strongly suggests histoplasmosis. The thin dogs are a key clue, as they are often associated with Histoplasma capsulatum, which is endemic in certain regions, including Spain. The symptoms and lab findings are consistent with disseminated histoplasmosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 004
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 24-year-old man presents after a 3-month backpacking trip to India. He initially developed watery, non-bloody diarrhea which resolved, and a stool culture at that time grew Campylobacter. Two weeks after returning home, he developed recurrent diarrhea, loss of appetite, bloating, and significant flatulence. He notes that his stools are particularly foul-smelling and difficult to flush. The patient has also started to lose weight. His doctor ordered stool microscopy to investigate for ova, cysts, and parasites.
# Patient age: 24
# Primary symptoms: Symptoms of diarrhea include diarrhea, loss of appetite, bloating, flatulence
#
# Assistant:
# **Predicted disease:** Giardiasis
# **Reason:** The patient's symptoms of recurrent diarrhea, loss of appetite, bloating, flatulence, and foul-smelling stools, along with a history of travel to India, strongly suggest Giardiasis. The initial Campylobacter infection could have predisposed him to Giardiasis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 005
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 60-year-old man from Ohio with a history of rheumatoid arthritis presents with severe dyspnea and cough. His medical history is significant for treatment with methotrexate, methylprednisolone, and infliximab, which was started ten weeks prior to presentation. His symptoms rapidly progressed to respiratory failure requiring mechanical ventilation. A chest radiograph revealed bilateral nodular infiltrates. Bronchoalveolar lavage fluid contained yeast forms, and a urine antigen test was markedly positive. The patient has normal blood cell counts.
# Patient age: 60
# Primary symptoms: list of symptoms
#
# Assistant:
# **Predicted disease:** Pulmonary Blastomycosis
# **Reason:** The patient's presentation with dyspnea, cough, bilateral nodular infiltrates on chest radiograph, yeast forms in bronchoalveolar lavage fluid, and a positive urine antigen test strongly suggests pulmonary blastomycosis. The patient's immunosuppressed state due to methotrexate, methylprednisolone, and infliximab further increases the likelihood of this opportunistic infection.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 006
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A staff sergeant was hospitalized after returning from a military exercise in Belize. He initially presented with fever, headache, and myalgia, but after a brief improvement, his condition deteriorated. He developed jaundice, signs of pneumonia, conjunctival inflammation, and hepatosplenomegaly. A chest X-ray showed bi-basal opacities. Laboratory results revealed neutrophilia, thrombocytopenia, elevated conjugated bilirubin, and mild elevation of transaminases. His condition progressed to oliguria and uremia, requiring renal support.
# Patient age: 0
# Primary symptoms: hemorrhagic fever, headache, myalgia, but after a brief improvement, his condition deteriorated
#
# Assistant:
# **Predicted disease:** Dengue Hemorrhagic Fever (DHF)
#
# **Reason:** The combination of fever, headache, myalgia, followed by a deterioration with jaundice, pneumonia, conjunctival inflammation, hepatosplenomegaly, bi-basal opacities on chest X-ray, thrombocytopenia, elevated conjugated bilirubin, and uremia strongly suggests Dengue Hemorrhagic Fever (DHF). The military exercise in Belize is a relevant epidemiological clue, as dengue is endemic in tropical regions.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 007
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 25-year-old male was hospitalized for vomiting blood. On examination, he was found to have an enlarged liver and spleen, and endoscopy confirmed the presence of esophageal varices. Blood tests revealed anemia and a significantly elevated eosinophil count. Serological tests for hepatitis B and C were negative, and the patient denied excessive alcohol use. A liver biopsy showed extensive granulomatous changes and fibrosis. Further history revealed he spent his childhood in Kenya where he frequently swam in a lake.
# Patient age: 25
# Primary symptoms: hepatitis B, C
#
# Assistant:
# **Predicted disease:** Schistosomiasis
# **Reason:** The patient's history of swimming in a lake in Kenya, along with the presence of esophageal varices, splenomegaly, anemia, elevated eosinophils, and granulomatous liver changes on biopsy strongly suggests schistosomiasis. The parasite *Schistosoma haematobium* is commonly found in lakes in Africa and can cause these symptoms.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 008
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 24-year-old man from Southern India presented with swelling of his left foot that diminishes overnight. He is afebrile and systemically well but reports a history of recurrent episodes of painful, swollen lymph nodes in his groin. On examination, he has enlarged inguinal lymph nodes. Laboratory evaluation was significant for a marked eosinophilia of 1.4×10^9 L–1, while D-dimers were normal. Filarial serology was positive. The patient noted that in his hometown, he had seen individuals with grossly swollen legs.
# Patient age: 24
# Primary symptoms: eosinophilia of 1.4109 L–1, D-dimers of 1.4109 L–1
#
# Assistant:
# **Predicted disease:** Lymphatic Filariasis
# **Reason:** The patient's presentation of recurrent painful, swollen lymph nodes, eosinophilia, positive filarial serology, and a history of seeing swollen legs in his hometown strongly suggests lymphatic filariasis. The nocturnal swelling of the foot is also consistent with lymphatic obstruction.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 009
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 28-year-old Kurdish refugee presented with a four-month history of upper abdominal pain and recent right-sided chest pain. He was afebrile and his weight was stable. An initial chest X-ray showed a mass in the right lung. A subsequent CT scan of the chest and abdomen demonstrated a cystic structure in his liver, with additional cysts in his chest. The right lung lesion was surgically excised for diagnosis. Histopathology of the excised tissue confirmed a parasitic etiology, and serologic tests were also positive.
# Patient age: 28
# Primary symptoms: List of symptoms of upper abdominal pain, recent right-sided chest pain
#
# Assistant:
# **Predicted disease:** Paragonimiasis (Lung Cysticercosis)
# **Reason:** The patient's age, symptoms (upper abdominal pain, right-sided chest pain), imaging findings (lung mass, liver cysts, chest cysts), and histopathology confirming a parasitic etiology strongly suggest Paragonimiasis (Lung Cysticercosis). This parasitic infection is common in endemic areas and often presents with pulmonary and hepatic involvement.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 010
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 63-year-old man living in a hostel for the homeless presents with a one-month history of weakness, weight loss, night fevers, and breathlessness. He recently began coughing up blood, which prompted him to seek care at a walk-in clinic. On examination, he had a low-grade fever and bronchial breathing was noted on chest auscultation. A chest X-ray was performed, which demonstrated apical shadowing and a large cavitation. A sputum sample was collected for analysis.
# Patient age: 63
# Primary symptoms: 63-year-old
#
# Assistant:
# **Predicted disease:** Tuberculosis
# **Reason:** The patient's age, symptoms (weakness, weight loss, night fevers, breathlessness, hemoptysis), and chest X-ray findings (apical shadowing, cavitation) are highly suggestive of tuberculosis. The patient's living situation in a homeless hostel also increases the likelihood of TB.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 011
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 32-year-old woman originally from Brazil presented with a sudden onset of left-sided weakness affecting her face, arm, and leg. She also reported recent shortness of breath on exertion. A CT scan of her brain confirmed an acute stroke. Her ECG was abnormal, showing broadened QRS complexes, and a chest X-ray demonstrated cardiomegaly. An echocardiogram revealed a dilated left ventricle with a characteristic apical aneurysm. A small thrombus was noted within the aneurysm, consistent with a cardioembolic source for her stroke.
# Patient age: 32
# Primary symptoms: Acute stroke: A dilated left ventricle with a characteristic apical aneurysm, consistent with a cardioembolic source for her stroke
#
# Assistant:
# **Predicted disease:** Endocarditis (specifically, infective endocarditis)
# **Reason:** The combination of a stroke, a dilated left ventricle with an apical aneurysm, and a cardioembolic source strongly suggests infective endocarditis. The patient's age and origin from Brazil also increase the likelihood of this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 012
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A university professor presents with malaise and headache after returning from a botanical expedition in Kenya. He developed a large, swollen, and painful black lesion on his thigh. An initial course of antibiotics for a suspected skin infection was ineffective, and his headache and myalgia persisted. Upon evaluation at a travel clinic, the lesion was identified as a tick bite. Physical examination also revealed regional lymphadenopathy. Blood was drawn for serology to confirm a suspected tick-borne illness before appropriate antibiotic therapy was started.
# Patient age: unknown
# Primary symptoms: lymphadenopathy
#
# Assistant:
# **Predicted disease:** African Tick-Bite Fever (ATBF)
# **Reason:** The patient's history of a tick bite in Kenya, followed by a painful, swollen, black lesion, headache, myalgia, and lymphadenopathy strongly suggests ATBF. The ineffective antibiotic treatment further supports this diagnosis, as ATBF is not typically bacterial.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 013
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 19-year-old woman presented for a routine gynecologic examination with a complaint of mid-cycle bleeding. She is sexually active with one partner and is taking oral contraceptives. On internal examination, a mucopurulent discharge was noted at the external cervical os. The cervix was also observed to be friable and bled easily on contact. An endocervical swab was collected for testing due to suspicion of a sexually transmitted infection, and the test result was positive.
# Patient age: 19
# Primary symptoms: An endocervical swab was collected for testing due to suspicion of a sexually transmitted infection, the test result was positive
#
# Assistant:
# **Predicted disease:** *Neisseria gonorrhoeae* infection (Gonorrhea)
# **Reason:** The patient's symptoms (mucopurulent cervical discharge, friable cervix, bleeding on contact) and a positive endocervical swab for a sexually transmitted infection strongly suggest gonorrhea.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 014
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 37-year-old woman from Southern Mexico presented with a persistent body rash. Her symptoms began five years prior with spasms and needle-like pain in her arms, accompanied by fatigue. She was initially treated for depression and atopic dermatitis. Physical examination revealed numerous hypopigmented skin lesions on her arms, face, abdomen, back, and legs. She also had thinning eyebrows and numbness in her forearm. A skin biopsy was taken from an abdominal lesion for analysis.
# Patient age: 37
# Primary symptoms: list of symptoms of atopic dermatitis
#
# Assistant:
# **Predicted disease:** Leprosy (Hansen's Disease)
# **Reason:** The combination of hypopigmented skin lesions, nerve damage (numbness in forearm), and a history of spasms and pain in the arms strongly suggests leprosy. The initial treatment for depression and atopic dermatitis being ineffective further supports this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 015
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 40-year-old male from Nepal presented with a four-day history of severe pain, swelling, and discoloration of his left hand. He reported being bitten by a snake on his left little finger four days prior and had not sought any medical care. On examination, he was febrile and tachycardic. There was a large, tense, fluctuant swelling on the dorsum of his left hand with overlying bluish skin discoloration, and the entire left little finger was black. Laboratory studies showed a high white blood cell count with a neutrophilic predominance. An ultrasound of the hand revealed a significant fluid collection consistent with an abscess.
# Patient age: 40
# Primary symptoms: list of symptoms of severe pain, swelling, discoloration of his left hand
#
# Assistant:
# **Predicted disease:** Anthrax
# **Reason:** The patient's presentation with a history of snake bite, fever, tachycardia, a large, tense, fluctuant swelling with bluish skin discoloration, and a blackened finger is highly suggestive of cutaneous anthrax. The neutrophilic leukocytosis further supports this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 016
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 34-year-old man with no significant past medical history presented with a two-week illness. His symptoms began with epigastric pain, nausea, decreased appetite, and fevers up to 39°C. One week into the illness, he developed right-sided pleuritic chest pain. On the day of admission, his symptoms persisted, and an abdominal ultrasound was performed. The imaging revealed hepatomegaly and a large, heterogeneous liver lesion measuring 13.4 x 3.6 cm.
# Patient age: 34
# Primary symptoms: hepatomegaly
#
# Assistant:
# **Predicted disease:** Amoebic Liver Abscess
# **Reason:** The patient's presentation of epigastric pain, nausea, fever, right-sided pleuritic chest pain, hepatomegaly, and a large heterogeneous liver lesion on ultrasound strongly suggests an amoebic liver abscess. The location of the lesion and the patient's age are also consistent with this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 017
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 70-year-old man from Peru presented with a six-year history of a slowly expanding, painless skin lesion on his left foot. The lesion initially appeared as a small, non-pruritic papule on the dorsum of the foot. Over the course of several years, this papule became ulcerated and failed to heal. The patient has no other significant past medical history and sought evaluation for this chronic, non-healing ulcer.
# Patient age: 70
# Primary symptoms: list of comma-separated symptoms
#
# Assistant:
# **Predicted disease:** Basal Cell Carcinoma
# **Reason:** Basal cell carcinoma (BCC) is the most common type of skin cancer and is strongly associated with sun exposure. While the patient's location (Peru) might suggest other tropical skin conditions, the description of a slowly expanding, painless, non-pruritic lesion that has failed to heal over several years is highly characteristic of BCC.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 018
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 52-year-old male farmer from rural Brazil presents with a six-month history of progressive weight loss, productive cough, and painful sores in his mouth. He has difficulty eating due to the oral lesions. On physical examination, he appears cachectic. The oropharynx reveals multiple ulcerative and granulomatous lesions on the gums and palate, described as having a mulberry-like appearance. Lung examination is notable for bilateral crackles. A chest radiograph shows bilateral, mixed interstitial and alveolar infiltrates, predominantly in the middle and lower lung zones.
# Patient age: 52
# Primary symptoms: List of ulcerative, granulomatous lesions on the gums, palate, described as having a mulberry-like appearance
#
# Assistant:
# **Predicted disease:** Tuberculosis
# **Reason:** The combination of progressive weight loss, productive cough, painful oral lesions (ulcerative and granulomatous, mulberry-like appearance), cachexia, bilateral crackles on lung auscultation, and bilateral interstitial and alveolar infiltrates on chest radiograph strongly suggests tuberculosis. The patient's occupation as a farmer in rural Brazil further increases the likelihood of exposure to *Mycobacterium tuberculosis*.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 019
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: An 18-year-old female presents with a five-day history of abrupt onset fever, shaking chills, generalized malaise, headache, and myalgias. She also reports nausea, vomiting, and dark urine that began two days prior to admission. Her symptoms began eight days after she returned from an 8-day trip to a jungle region in Iquitos, Peru. During her trip, she slept in tents, swam in a river, and had inconsistent use of mosquito repellents and nets. On examination, she is febrile to 38°C and tachycardic with a heart rate of 110 bpm. The exam is notable for tenderness to palpation in both abdominal flanks, but no jaundice, rash, or signs of bleeding are present.
# Patient age: 18
# Primary symptoms: List of symptoms of abrupt onset fever, shaking chills, generalized malaise, headache, myalgias
#
# Assistant:
# **Predicted disease:** Leptospirosis
# **Reason:** The patient's recent travel to a jungle region in Peru, coupled with the abrupt onset of fever, chills, myalgias, headache, nausea, vomiting, dark urine, and abdominal flank tenderness, strongly suggests leptospirosis. The inconsistent use of mosquito repellents and nets further increases the likelihood of exposure to the bacteria.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 020
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 68-year-old man with a history of benign prostatic hyperplasia presented with a chronic dermatological complaint. For the past seven months, he has developed scaly skin lesions spread across his body. The lesions are associated with severe and persistent itching. The condition has been progressive over this multi-month period. No other systemic symptoms or relevant exposures are mentioned in the initial history.
# Patient age: 68
# Primary symptoms: list of scaly skin lesions
#
# Assistant:
# **Predicted disease:** Psoriasis
# **Reason:** While the patient's age and chronic, itchy, scaly skin lesions are suggestive of psoriasis, the lack of systemic symptoms and specific exposures makes it less likely than other tropical diseases. Psoriasis is a chronic inflammatory skin condition that can occur at any age, but it is not typically associated with tropical environments.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 021
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A female neonate was born in the Democratic Republic of Congo to a 22-year-old mother who was diagnosed with Ebola virus disease via PCR at 34 weeks of gestation. The mother recovered after one week of supportive care. The infant was delivered vaginally at 38 weeks gestation with excellent Apgar scores and a normal physical examination. Multiple diagnostic tests were performed on the newborn at birth. Umbilical cord blood PCR, peripheral blood swabs, and salivary swabs were all negative for Ebola virus. The infant was discharged home and was growing normally at a one-month follow-up appointment.
# Patient age: 22
# Primary symptoms: The infant was born vaginally at 38 weeks gestation with excellent Apgar scores, a normal physical examination. Multiple diagnostic tests were performed on the newborn at birth. Umbilical cord blood PCR, peripheral blood swabs, salivary swabs were all negative for Ebola
#
# Assistant:
# **Predicted disease:** Congenital Zika Syndrome
# **Reason:** The infant was born to a mother who had Ebola virus disease. While the infant's initial tests were negative for Ebola, the mother's history of Ebola raises the possibility of a congenital infection. Zika virus is a known cause of congenital infections, and the clinical presentation of the infant (normal physical examination, excellent Apgar scores) is consistent with a mild or asymptomatic infection.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 022
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 7-year-old boy in Texas presented with a two-day history of right-hand pruritus and arm pain. Over the next few days, his condition worsened to include a rash, delusions, spasms, high fever, hypersalivation, and altered mental status, requiring intubation for airway protection. An extensive initial workup for common central nervous system infections, including various viruses and bacteria, was negative. A detailed history subsequently revealed that the child had been bitten by a bat approximately two months before symptom onset. No post-exposure prophylaxis was administered at the time of the bite because there were no visible marks.
# Patient age: 7
# Primary symptoms: list of symptoms
#
# Assistant:
# **Predicted disease:** Rabies
# **Reason:** The history of a bat bite, followed by progressive neurological symptoms including pruritus, arm pain, rash, delusions, spasms, high fever, hypersalivation, and altered mental status, is highly suggestive of rabies. The negative workup for common CNS infections further supports this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 023
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: An 18-year-old, previously healthy, unvaccinated postpartum woman presented to the emergency department with acute onset of severe dyspnea, chest pain, and respiratory distress. Her symptoms developed approximately six weeks after recovering from an acute viral illness. On arrival, she was tachycardic to 170 beats per minute, tachypneic, and severely hypoxic with an oxygen saturation of 79% on high-flow oxygen. Physical examination revealed diminished breath sounds bilaterally. An initial chest radiograph and subsequent CT scan confirmed a right-sided tension pneumothorax, a minimal left-sided pneumothorax, and diffuse ground-glass opacities with consolidation. She later developed a contralateral tension pneumothorax requiring a second chest tube.
# Patient age: 18
# Primary symptoms: comma-separated list
#
# Assistant:
# **Predicted disease:** Tropical Spontaneous Pneumothorax (TSP)
# **Reason:** The patient's age, recent viral illness, postpartum status, acute onset of severe respiratory distress with pneumothorax, and diffuse ground-glass opacities/consolidation are highly suggestive of TSP. The presence of a tension pneumothorax, especially contralateral, further supports this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 024
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: An 18-year-old boy from a dengue-endemic area in Sri Lanka presented with a one-day history of high fever, followed by a generalized tonic-clonic seizure and subsequent left-sided hemiparesis. On examination, he was drowsy with a GCS of 10, and had a left upper motor neuron facial palsy with flaccid paralysis of his left arm and leg. Initial brain CT was normal, but an MRI showed changes suggestive of right-sided meningoencephalitis. Over the next few days, he developed leukopenia, severe thrombocytopenia (23,000 cells/μl), and markedly elevated liver transaminases (AST >4900 U/L). He also showed signs of plasma leakage, including a rising hematocrit and free fluid on ultrasound.
# Patient age: 18
# Primary symptoms: List of symptoms of high fever, left-sided hemiparesis
#
# Assistant:
# **Predicted disease:** Dengue Hemorrhagic Fever (DHF)
#
# **Reason:** The patient's presentation with high fever, seizure, hemiparesis, leukopenia, thrombocytopenia, elevated liver enzymes, and plasma leakage strongly suggests Dengue Hemorrhagic Fever (DHF). The MRI findings of meningoencephalitis are also consistent with DHF.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 025
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 47-year-old Belgian woman, who was not vaccinated, developed an acute illness during a one-week vacation in The Gambia. Her symptoms began with high fever, chills, headache, back pain, and severe asthenia. Upon returning to Europe, she was admitted to an intensive care unit with jaundice, anuria, and profound weakness. Laboratory evaluation revealed thrombocytopenia, leukopenia, acute kidney injury, and extremely elevated liver transaminases (AST 49,000 U/L, ALT 23,000 U/L). She subsequently developed a severe coagulopathy with an elevated INR, leading to bleeding from injection sites and massive gastrointestinal hemorrhage, which resulted in hypovolemic shock and death.
# Patient age: 47
# Primary symptoms: List of symptoms of acute illness
#
# Assistant:
# **Predicted disease:** Dengue Hemorrhagic Fever (DHF)
#
# **Reason:** The patient's presentation with acute fever, headache, back pain, asthenia, jaundice, anuria, thrombocytopenia, leukopenia, acute kidney injury, extremely elevated liver transaminases, coagulopathy, and subsequent bleeding and hypovolemic shock strongly suggests Dengue Hemorrhagic Fever (DHF). The travel history to The Gambia, a region endemic for dengue, further supports this diagnosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 026
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 36-year-old female nurse in Nigeria presented with a three-day history of high-grade fever, chills, severe headache, and vomiting. She had not improved after treatment with antimalarials and ciprofloxacin. On admission, she was febrile, toxic-appearing, dehydrated, and hypotensive with a blood pressure of 80/60 mmHg. Her condition worsened over the next day with a fever spike to 40.0°C, restlessness, facial puffiness, and respiratory distress with basal lung crepitations. A bedside whole blood clotting time was markedly prolonged at over 20 minutes, although no overt bleeding was observed. Initial laboratory tests showed a normal white blood cell count and negative blood and urine cultures.
# Patient age: 36
# Primary symptoms: list of febrile, toxic-appearing, dehydrated, hypotensive
#
# Assistant:
# **Predicted disease:** Dengue Hemorrhagic Fever (DHF)
# **Reason:** The patient's presentation with high fever, severe headache, vomiting, thrombocytopenia (implied by prolonged clotting time), and signs of plasma leakage (facial puffiness, respiratory distress, hypotension) strongly suggests DHF. The failure to respond to antimalarials and ciprofloxacin further supports this diagnosis, as these medications are not effective against DHF.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 027
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 79-year-old male farmer from China presented with high-grade fever, progressive dyspnea, and cough three days after a known tick bite. Initial laboratory evaluation revealed profound thrombocytopenia (25×10^9/L) and leukopenia (1.24×10^9/L). His condition rapidly deteriorated, leading to progressive multiorgan failure with severe metabolic acidosis, acute liver and kidney injury, and hypoxemic respiratory failure. Neurological involvement was prominent, with altered mental status, nuchal rigidity, and a declining Glasgow Coma Scale score. Despite aggressive critical care, the patient's condition progressed to refractory viral sepsis and he ultimately died.
# Patient age: 79
# Primary symptoms: List of symptoms, symptoms of thrombocytopenia (25109/L), leukopenia (25109/L)
#
# Assistant:
# **Predicted disease:** Dengue Hemorrhagic Fever (DHF)
#
# **Reason:** The patient's presentation with high-grade fever, thrombocytopenia, leukopenia, progressive dyspnea, multiorgan failure, and neurological involvement following a tick bite strongly suggests Dengue Hemorrhagic Fever (DHF). The rapid progression to severe complications and death is also consistent with DHF. While other tropical diseases could present with some of these symptoms, the combination, particularly the thrombocytopenia and leukopenia, points most strongly to DHF.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 028
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 57-year-old immunocompromised female with a history of rheumatoid arthritis on methotrexate presented with a 24-hour history of diffuse abdominal pain, nausea, and diarrhea. She also reported a cough and headache. On examination, she was found to have multiple skin lesions in various stages of evolution, including pustules, papules, and vesicles, distributed across her body. The patient had a history of travel to a coastal area one month prior. Laboratory tests showed an elevated C-reactive protein, and a chest CT scan revealed multiple diffuse solid nodules in both lungs with ground-glass opacities.
# Patient age: 57
# Primary symptoms: 57-year-old immunocompromised female with rheumatoid arthritis on methotrexate presented with a 24-hour history of diffuse abdominal pain, nausea, diarrhea
#
# Assistant:
# **Predicted disease:** Lymphogranuloma venereum (LGV)
# **Reason:** The patient's immunocompromised state (methotrexate use), travel history to a coastal area, and the presence of skin lesions in various stages (pustules, papules, vesicles) are highly suggestive of LGV. The abdominal pain, nausea, and diarrhea are also consistent with LGV. The chest CT findings of diffuse solid nodules and ground-glass opacities are less typical for LGV but can be seen in disseminated disease.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 029
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 27-year-old Ugandan woman with a 10-year history of well-controlled HIV presented with a two-month history of worsening right lower abdominal pain and low-grade fevers. She had a remote history of lower back pain treated as lumbago two years prior, but denied recent constitutional symptoms like cough or weight loss. Examination revealed a palpable, tender mass in the right iliac fossa and a gibbus deformity with tenderness over the lumbar spine. An initial ultrasound suggested a psoas abscess. A subsequent abdominal CT scan showed extensive lytic destruction of the L1-L4 vertebral bodies and a large, rim-enhancing paravertebral cystic mass extending from the lumbar spine into the retroperitoneal space and right thigh.
# Patient age: 27
# Primary symptoms: X-rays showed a palpable, tender mass in the right iliac fossa, a gibbus deformity with tenderness over the lumbar spine
#
# Assistant:
# **Predicted disease:** Pott's disease (Tuberculosis of the spine)
# **Reason:** The patient's age, history of HIV (increasing susceptibility to TB), location of the mass (spinal region), and imaging findings (lytic destruction of vertebral bodies, paravertebral cystic mass) are highly suggestive of Pott's disease. The gibbus deformity is a classic sign of vertebral collapse due to TB infection.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 030
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 10-year-old Tibetan girl presented with a two-month history of moderate to severe headache and nonprojectile vomiting. She had no fever or initial seizures. An important epidemiological clue was that six of her schoolmates presented with similar symptoms and were suspected of having cysticercosis. Laboratory tests showed a mild peripheral eosinophilia and slightly elevated protein and white blood cell counts in the cerebrospinal fluid. A brain MRI was performed and showed numerous cystic lesions throughout the cerebral hemispheres, brain stem, and cerebellum. Some of these lesions had a characteristic "hole-with-dot" appearance, and serum ELISA was positive for IgG antibodies against cysticerci.
# Patient age: 10
# Primary symptoms: list of cystic lesions in the cerebral hemispheres, brain stem, cerebellum
#
# Assistant:
# **Predicted disease:** Neurocysticercosis
# **Reason:** The patient's age, symptoms (headache, vomiting), epidemiological link to cysticercosis, eosinophilia, elevated CSF protein and WBC, and the characteristic "hole-with-dot" appearance on brain MRI, along with positive IgG antibodies against cysticerci, strongly point to neurocysticercosis.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 031
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 49-year-old man was hospitalized for fever, rigors, and diarrhea. His medical history is significant for a trip to Peru eight weeks prior. Shortly after returning, he experienced a week-long febrile illness with myalgia, which resolved. However, his symptoms of fever and rigors recurred, and he developed multiple red vascular cutaneous nodules on his trunk and legs. On admission, laboratory tests revealed anemia (Hb 8.3 g/dl), an elevated white blood cell count, and a high C-reactive protein level of 210. Liver function tests were also abnormal, and a blood culture was positive for Salmonella enteritidis. Tests for malaria, dengue, and other common travel-related infections were negative.
# Patient age: 49
# Primary symptoms: List of symptoms of fever, rigors, diarrhea
#
# Assistant:
# **Predicted disease:** Cutaneous Tuberculosis
# **Reason:** The patient's history of travel to Peru, followed by a febrile illness with myalgia, and the subsequent development of red vascular cutaneous nodules, along with anemia, elevated WBC, elevated CRP, and abnormal liver function tests, strongly suggests a disseminated form of tuberculosis. The positive blood culture for Salmonella enteritidis is a red herring, as it is a common infection that can occur in any patient. The most likely diagnosis is cutaneous tuberculosis, given the clinical presentation.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 032
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 30-year-old male presented with fever, night sweats, backache, and hip pain after returning from Cyprus. He was referred to a hospital for investigation of a pyrexia of unknown origin. On examination, hepato-splenomegaly was noted. A temperature chart recorded by the patient showed an undulant pattern over several weeks. Laboratory tests revealed anemia, neutropenia, and thrombocytopenia, with slightly elevated transaminases. A chest X-ray was normal and a T-spot test for tuberculosis was negative.
# Patient age: 30
# Primary symptoms: hepato-splenomegaly
#
# Assistant:
# **Predicted disease:** Visceral Leishmaniasis (Kala-Azar)
# **Reason:** The combination of fever, night sweats, backache, hip pain, hepatosplenomegaly, anemia, neutropenia, thrombocytopenia, and an undulant fever pattern in a patient returning from Cyprus strongly suggests visceral leishmaniasis. The negative T-spot test makes tuberculosis less likely.
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 033
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 38-year-old man presented with a one-week history of high-grade intermittent fever, rigors, chills, headache, retro-orbital pain, and myalgia. For the past two days, he has also experienced reddish-colored urine with clots and two episodes of gum bleeding. On physical examination, his vital signs were stable, but he had multiple purpura and petechiae on his shoulder, trunk, and legs, as well as large ecchymotic lesions on his back. Laboratory studies revealed a very low platelet count of 20,000/μL and a low white blood cell count of 2.4 x 10^9/L. A tourniquet test was also positive.
# Patient age: 38
# Primary symptoms: Symptoms of intermittent fever, rigors, chills, headache, retro-orbital pain, myalgia
#
# Assistant:
# **Predicted disease:** Dengue Hemorrhagic Fever (DHF)
# **Reason:** The combination of high-grade fever, headache, retro-orbital pain, myalgia, thrombocytopenia (low platelet count), leukopenia (low white blood cell count), positive tourniquet test (indicating increased capillary permeability), and purpura/petechiae/ecchymoses strongly suggests Dengue Hemorrhagic Fever (DHF).
#
# Latency: 0.00s

# %%
# SAVE TO EXCEL
import pandas as pd
df = pd.DataFrame(testcase_results)
output_path = "/content/testcase_medgemma_without_rag.xlsx"
df.to_excel(output_path, index=False)
print(f"\nExcel saved to: {output_path}")
# Out:
# Excel saved to: /content/testcase_medgemma_without_rag.xlsx

# %% [markdown]
# # MedGemma with RAG

# %%
import os
import re
import time
import warnings
import yaml
from functools import lru_cache
from typing import Any, Dict, List, Optional, Union
import requests
import torch
from transformers import pipeline
from PIL import Image
from io import BytesIO
from pathlib import Path

# Initialize the MedGemma 4B model with optional quantization
pipe = pipeline(
    "image-text-to-text",
    model="google/medgemma-4b-it",
    dtype=torch.bfloat16,
    device="cuda" if torch.cuda.is_available() else "cpu",
)

# Configure dataset path and inference options
TEST_DATA_ROOT = Path("/content/drive/MyDrive/Data/Test-Data/extracted-data")
USE_RAG = False  # Set True to enable retrieval with the original case text
MAX_CASES = None  # Set to an integer to cap processed cases

KEYWORD_MODEL_DEFAULT = os.getenv("RAG_KEYWORD_MODEL", "google/flan-t5-small")
KEYWORD_PROMPT_DEFAULT = os.getenv(
    "RAG_KEYWORD_PROMPT",
    (
        "Extract up to {max_keywords} concise clinical keywords or short phrases "
        "from the following request. Return only a comma-separated list without numbering.\n"
        "Request: {prompt}"
    ),
)

@lru_cache(maxsize=4)
def get_keyword_extractor(model_id: str = KEYWORD_MODEL_DEFAULT):
    device = 0 if torch.cuda.is_available() else -1
    return pipeline("text2text-generation", model=model_id, device=device)

def extract_keywords_with_llm(
    prompt_text: str,
    *,
    max_keywords: int = 6,
    model_id: Optional[str] = None,
    instruction_template: Optional[str] = None,
    **generate_kwargs: Any,
 ) -> List[str]:
    """Use a small seq2seq model to extract search-oriented keywords."""
    if not prompt_text or not prompt_text.strip():
        return []
    chosen_model = model_id or KEYWORD_MODEL_DEFAULT
    instruction = (
        instruction_template or KEYWORD_PROMPT_DEFAULT
    ).format(
        max_keywords=max_keywords,
        prompt=prompt_text.strip(),
        user_prompt=prompt_text.strip(),
    )
    extractor = get_keyword_extractor(chosen_model)
    response = extractor(
        instruction,
        max_new_tokens=64,
        num_return_sequences=1,
        **generate_kwargs,
    )
    generated = ""
    if response and isinstance(response, list):
        candidate = response[0]
        generated = candidate.get("generated_text") or candidate.get("text") or ""
    raw_tokens = re.split(r"[\n,;]|\band\b", generated)
    seen: set[str] = set()
    keywords: List[str] = []
    for token in raw_tokens:
        cleaned = token.strip("\t :.-\u2022\u2023\uf0b7")
        if not cleaned:
            continue
        lowered = cleaned.lower()
        if lowered in seen:
            continue
        seen.add(lowered)
        keywords.append(cleaned)
        if len(keywords) >= max_keywords:
            break
    return keywords

def render_text_template(
    base_text: Optional[str],
    *,
    template: Optional[str] = None,
    variables: Optional[Dict[str, Any]] = None,
    field_name: str = "prompt",
    defaults: Optional[Dict[str, Any]] = None,
 ) -> str:
    """Render free-form text using a format template when provided."""
    text_value = base_text or ""
    if template:
        template_vars: Dict[str, Any] = {
            "prompt": text_value,
            "user_prompt": text_value,
        }
        if defaults:
            template_vars.update(defaults)
        if variables:
            template_vars.update(variables)
        try:
            rendered = template.format(**template_vars)
        except KeyError as exc:
            missing_key = exc.args[0] if exc.args else "unknown"
            raise ValueError(f"{field_name} template expects variable '{missing_key}'.") from exc
        if rendered.strip():
            return rendered
        if text_value.strip():
            return text_value
        raise ValueError(f"{field_name.title()} template rendered an empty string.")
    if text_value.strip():
        return text_value
    raise ValueError(f"Provide a {field_name} or {field_name} template.")

def load_image(image_url: Optional[str] = None, image_path: Optional[str] = None):
    """Load an image from a URL or disk, returning the PIL image or an error dict."""
    if image_url:
        try:
            response = requests.get(image_url)
            response.raise_for_status()
            image_obj = Image.open(BytesIO(response.content))
            image_obj.verify()
            image_obj = Image.open(BytesIO(response.content))
            return image_obj
        except Exception as exc:
            return {"error": "Failed to load image", "message": str(exc)}
    if image_path:
        try:
            image_obj = Image.open(image_path)
            image_obj.verify()
            image_obj = Image.open(image_path)
            return image_obj
        except Exception as exc:
            return {"error": "Failed to load image", "message": str(exc)}
    return None

def find_case_images(case_dir: Path) -> list[Path]:
    image_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif', '.webp'}
    image_files = []

    for ext in image_extensions:
        image_files.extend(case_dir.glob(f"*{ext}"))
        image_files.extend(case_dir.glob(f"*{ext.upper()}"))

    images_dir = case_dir / "images"
    if images_dir.exists() and images_dir.is_dir():
        for ext in image_extensions:
            image_files.extend(images_dir.glob(f"*{ext}"))
            image_files.extend(images_dir.glob(f"*{ext.upper()}"))

    return sorted(image_files)

def load_case_images(case_dir: Path) -> list[Image.Image]:
    image_paths = find_case_images(case_dir)
    loaded_images = []

    for img_path in image_paths:
        try:
            image = Image.open(img_path)
            image.verify()
            image = Image.open(img_path)
            loaded_images.append(image)
        except Exception as e:
            print(f"Failed to load image {img_path.name}: {e}")
    return loaded_images

def build_system_content(system_instruction: str, context: str = "") -> List[Dict[str, Any]]:
    """Build system content for MedGemma."""
    content = [{"type": "text", "text": system_instruction}]
    if context:
        content.append({"type": "text", "text": f"Context: {context}"})
    return content

def build_user_content(prompt: str, image: Optional[Image.Image] = None) -> List[Dict[str, Any]]:
    """Build user content for MedGemma."""
    content = [{"type": "text", "text": prompt}]
    if image:
        content.append({"type": "image", "image": image})
    return content

def extract_answer_from_response(response) -> str:
    """Extract the answer text from MedGemma's response structure."""
    if not response:
        return "No answer."

    if isinstance(response, list) and len(response) > 0:
        generated_item = response[0]

        if isinstance(generated_item, dict) and "generated_text" in generated_item:
            generated_text = generated_item["generated_text"]

            if isinstance(generated_text, list):
                for msg in reversed(generated_text):
                    if isinstance(msg, dict) and msg.get("role") == "assistant":
                        content = msg.get("content", "")
                        if isinstance(content, list):
                            for chunk in content:
                                if isinstance(chunk, dict) and chunk.get("type") == "text":
                                    return chunk.get("text", "No text found")
                        elif isinstance(content, str):
                            return content
                        return str(content)

                last_msg = generated_text[-1]
                if isinstance(last_msg, dict) and "content" in last_msg:
                    return last_msg["content"]

            elif isinstance(generated_text, str):
                return generated_text

        elif isinstance(generated_item, str):
            return generated_item

    return str(response)

def _extract_predicted_disease(answer: str) -> str:
    """Extract predicted disease from answer text."""
    if not answer:
        return ""

    patterns = [
        r"Predicted disease:\s*(.+)",
        r"Diagnosis:\s*(.+)",
        r"Condition:\s*(.+)",
        r"Disease:\s*(.+)"
    ]

    for pattern in patterns:
        match = re.search(pattern, answer, flags=re.IGNORECASE)
        if match:
            return match.group(1).strip()

    return answer.strip()

def run_medgemma(
    prompt: Optional[str] = None,
    *,
    prompt_template: Optional[str] = None,
    prompt_variables: Optional[Dict[str, Any]] = None,
    image: Optional[Image.Image] = None,
    system_instruction: str = "You are an expert in tropical diseases.",
    system_instruction_template: Optional[str] = None,
    system_instruction_variables: Optional[Dict[str, Any]] = None,
    max_new_tokens: int = 2000,
    temperature: float = 0.0,
    **generate_kwargs: Any,
 ) -> Dict[str, Any]:
    """Generate an answer with MedGemma without RAG context."""
    start_time = time.time()
    output: Dict[str, Any] = {
        "answer": None,
        "latency": None,
        "error": None,
        "resolved_prompt": None,
        "resolved_system_instruction": None,
        "predicted": None,
    }

    # Render final prompt
    try:
        final_prompt = render_text_template(
            prompt,
            template=prompt_template,
            variables=prompt_variables,
            field_name="prompt",
        )
        output["resolved_prompt"] = final_prompt
    except Exception as e:
        output["error"] = f"Prompt rendering error: {e}"
        output["latency"] = time.time() - start_time
        return output

    # Render system instruction
    try:
        final_system_instruction = render_text_template(
            system_instruction,
            template=system_instruction_template,
            variables=system_instruction_variables,
            field_name="system instruction",
            defaults={"final_prompt": final_prompt},
        )
        output["resolved_system_instruction"] = final_system_instruction
    except Exception as e:
        output["error"] = f"System instruction rendering error: {e}"
        output["latency"] = time.time() - start_time
        return output

    # Build messages for MedGemma
    system_content = build_system_content(final_system_instruction)
    user_content = build_user_content(
        final_prompt,
        image=image if isinstance(image, Image.Image) else None,
    )
    messages = [
        {"role": "system", "content": system_content},
        {"role": "user", "content": user_content},
    ]

    try:
        response = pipe(
            messages,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            **generate_kwargs,
        )

        # Extract the answer text properly
        output["model_response"] = response[0]["generated_text"][-1]["content"] if response else "No answer."
        generated = response[0].get("generated_text")
        extracted_anw = extract_answer_from_response(response)
        output["answer"] = generated
        # Extract prediction
        output["predicted"] = _extract_predicted_disease(extracted_anw)


    except Exception as exc:
        output["error"] = f"Model inference error: {exc}"
    finally:
        output["latency"] = time.time() - start_time

    return output

def run_medgemma_rag(
    prompt: Optional[str] = None,
    *,
    prompt_template: Optional[str] = None,
    prompt_variables: Optional[Dict[str, Any]] = None,
    image: Optional[Image.Image] = None,
    rag_query: Optional[str] = None,
    rag_top_k: Optional[int] = None,
    rag_use_keyword_llm: bool = False,
    rag_keyword_model_id: Optional[str] = None,
    rag_keyword_max_items: int = 6,
    rag_keyword_prompt: Optional[str] = None,
    system_instruction: str = "You are an expert in tropical diseases.",
    system_instruction_template: Optional[str] = None,
    system_instruction_variables: Optional[Dict[str, Any]] = None,
    max_new_tokens: int = 2000,
    temperature: float = 0.0,
    **generate_kwargs: Any,
 ) -> Dict[str, Any]:
    """Generate an answer with MedGemma using RAG context when available."""
    start_time = time.time()
    output: Dict[str, Any] = {
        "answer": None,
        "citations": [],
        "context": "",
        "references": [],
        "latency": None,
        "error": None,
        "resolved_prompt": None,
        "resolved_system_instruction": None,
        "rag_query_used": None,
        "rag_keywords": [],
        "predicted": None,
    }

    # Render final prompt
    final_prompt = render_text_template(
        prompt,
        template=prompt_template,
        variables=prompt_variables,
        field_name="prompt",
)
    output["resolved_prompt"] = final_prompt


    # Extract keywords for RAG if enabled
    keyword_query: Optional[str] = None
    extracted_keywords: List[str] = []
    if rag_use_keyword_llm and final_prompt.strip():
        extracted_keywords = extract_keywords_with_llm(
            final_prompt,
            max_keywords=rag_keyword_max_items,
            model_id=rag_keyword_model_id,
            instruction_template=rag_keyword_prompt,
        )
        if extracted_keywords:
            keyword_query = ", ".join(extracted_keywords)
            output["rag_keywords"] = extracted_keywords

    # Gather RAG context
    context_text = ""
    references = []
    if rag_query is not False:
        if isinstance(rag_query, str) and rag_query.strip():
            query_source = rag_query.strip()
        elif keyword_query:
            query_source = keyword_query
        else:
            query_source = final_prompt

        context_text, references = gather_rag_context(query_source, top_k=rag_top_k)
        output["context"] = context_text
        output["references"] = references
        output["rag_query_used"] = query_source

    # Render system instruction
    try:
        final_system_instruction = render_text_template(
            system_instruction,
            template=system_instruction_template,
            variables=system_instruction_variables,
            field_name="system instruction",
            defaults={
                "final_prompt": final_prompt,
                "rag_has_matches": bool(references),
            },
        )
        output["resolved_system_instruction"] = final_system_instruction
    except Exception as e:
        output["error"] = f"System instruction rendering error: {e}"
        output["latency"] = time.time() - start_time
        return output

    # Build messages with RAG context
    system_content = build_system_content(final_system_instruction, context=context_text)
    user_content = build_user_content(
        final_prompt,
        image=image if isinstance(image, Image.Image) else None,
    )
    messages = [
        {"role": "system", "content": system_content},
        {"role": "user", "content": user_content},
    ]

    try:
        response = pipe(
            messages,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            **generate_kwargs,
        )

        # Extract the answer
        generated = response[0].get("generated_text") if response else None
        output["model_response"] = response[0]["generated_text"][-1]["content"] if response else "No answer."
        output["answer"] = generated or "No answer."
        extracted_answer = extract_answer_from_response(response)
        output["predicted"] = _extract_predicted_disease(extracted_answer)

    except Exception as exc:
        output["error"] = f"Model inference error: {exc}"
    finally:
        output["latency"] = time.time() - start_time

    # Process citations
    if references:
        citations = []
        for ref in references:
            payload = ref.get("payload", {})
            citation_info = {
                "case_id": payload.get("case_id"),
                "meta_ref":payload.get("meta_ref"),
                "chunk_id": payload.get("chunk_id"),
                "source_pdf": f'https://{payload.get("source_pdf")}'
            }
            citations.append(citation_info)
        output["citations"] = citations

    return output

def _format_chat_like_answer(answer: Any) -> str:
    """Convert chat-style answers into a readable text block."""
    if answer is None:
        return ""
    if isinstance(answer, str):
        return answer
    if not isinstance(answer, list):
        return str(answer)

    formatted_lines: List[str] = []
    for message in answer:
        if not isinstance(message, dict):
            formatted_lines.append(str(message))
            continue
        role = str(message.get("role", "assistant")).strip() or "assistant"
        content = message.get("content")
        segments: List[str] = []
        if isinstance(content, list):
            for chunk in content:
                if not isinstance(chunk, dict):
                    segments.append(str(chunk))
                    continue
                chunk_type = chunk.get("type")
                if chunk_type == "text":
                    text = chunk.get("text")
                    if text:
                        segments.append(str(text))
                elif chunk_type == "image":
                    segments.append("[Image provided]")
        elif content is not None:
            segments.append(str(content))

        body = "\n".join(seg for seg in segments if seg).strip()
        if body:
            header = role.title()
            formatted_lines.append(f"{header}:\n{body}")
    return "\n\n".join(formatted_lines).strip()

def pretty_print_result(result) -> None:
    """Utility to display the result in a readable form."""
    if isinstance(result, list):
        for i, case_result in enumerate(result):
            print(f"\n{'='*50}")
            print(f"Case ID: {case_result.get('case_id', 'Unknown')}")
            print(f"{'='*50}")
            _print_single_result(case_result)
        return

    _print_single_result(result)

def _print_single_result(result) -> None:
    """Print a single case result."""
    if result.get("error"):
        print("Error:", result["error"])
        return
    if result.get("resolved_prompt"):
        print("Prompt (resolved):\n", result["resolved_prompt"])
    if result.get("rag_keywords"):
        print("\nKeywords for retrieval:")
        print(", ".join(result["rag_keywords"]))
    answer_text = _format_chat_like_answer(result.get("answer"))
    print("\nAnswer:\n", answer_text)
    if result.get("predicted"):
        print(f"\nPredicted disease: {result.get('predicted')}")
    if result.get("context"):
        print("\nContext (truncated):\n", result["context"][:500])
    if result.get("citations"):
        print("\nCitations:")
        for i, citation in enumerate(result.get("citations", []), 1):
            print(f"[{i}] {citation}")
    print(f"\nLatency: {result.get('latency', 0.0):.2f}s")

def derive_prompt_variables(
    user_prompt: str,
    symptom_limit: int = 12,
    age_model_id: Optional[str] = None,
    symptom_model_id: Optional[str] = None,
) -> Dict[str, Any]:
    """Build template variables via the keyword LLM to keep prompts DRY."""
    if not user_prompt or not user_prompt.strip():
        return {}
    variables: Dict[str, Any] = {}

    # Extract age using regex
    age_match = re.search(r'(\d{1,3})\s*[- ]?\s*(year|years|yr|yo|y/o)[- ]?(old)?', user_prompt.lower())
    if age_match:
        try:
            variables["age"] = int(age_match.group(1))
        except ValueError:
            variables["age"] = "unknown"
    else:
        # Fallback to LLM if regex fails
        age_instruction = (
            "Extract the patient's age from the statement. "
            "Respond with a single number if the age is given, otherwise respond with NONE.\n"
            "Patient statement: {prompt}"
        )
        age_candidates = extract_keywords_with_llm(
            user_prompt,
            max_keywords=1,
            model_id=age_model_id,
            instruction_template=age_instruction,
        )
        for token in age_candidates:
            digit_match = re.search(r"\d{1,3}", token)
            if digit_match:
                try:
                    variables["age"] = int(digit_match.group())
                    break
                except ValueError:
                    continue

    # Extract symptoms
    symptom_instruction = (
        "List up to {max_keywords} concise clinical symptoms or findings mentioned by the patient. "
        "Return a comma-separated list without numbering.\n"
        "Patient statement: {prompt}"
    )
    symptoms = extract_keywords_with_llm(
        user_prompt,
        max_keywords=symptom_limit,
        model_id=symptom_model_id,
        instruction_template=symptom_instruction,
    )
    if symptoms:
        variables["symptoms"] = ", ".join(symptoms)

    # Set defaults
    if "age" not in variables:
        variables["age"] = "unknown"
    if "symptoms" not in variables:
        variables["symptoms"] = "unspecified"

    return variables

def run_diagnosis_testcase(use_rag: bool = USE_RAG, max_cases: Optional[int] = MAX_CASES):
    """Run diagnosis test cases with optional RAG."""
    if not TEST_DATA_ROOT.exists():
        raise FileNotFoundError(f"Test data directory not found: {TEST_DATA_ROOT}")

    results = []
    case_counter = 0

    print(f"Scanning for cases in: {TEST_DATA_ROOT}")
    print(f"Using RAG: {use_rag}")

    for case_dir in sorted(TEST_DATA_ROOT.iterdir()):
        if max_cases is not None and case_counter >= max_cases:
            break
        if not case_dir.is_dir():
            continue

        query_path = case_dir / "query.txt"
        if not query_path.exists():
            continue

        # Read user prompt
        user_prompt = query_path.read_text(encoding="utf-8").strip()
        prompt_variables = derive_prompt_variables(
            user_prompt=user_prompt,
            symptom_limit=12,
        )

        # Load prompt template
        prompt_type = "clinical_qa"
        try:
            with open(f'/content/prompts/medgemma/{prompt_type}.yaml', 'r') as file:
                config = yaml.safe_load(file)
            prompt_template = config['prompt_template']
            system_instruction = config['system_prompt']
        except Exception as e:
            print(f"Warning: Could not load prompt template: {e}")
            # Fallback templates
            prompt_template = "Patient query: {prompt}\n\nPlease provide a diagnosis."
            system_instruction = "You are a medical expert specializing in tropical diseases."

        # Load images
        case_images = load_case_images(case_dir)
        image = case_images[0] if case_images else None

        # Run inference with or without RAG
        if use_rag:
            response = run_medgemma_rag(
                prompt=user_prompt,
                prompt_template=prompt_template,
                prompt_variables=prompt_variables,
                image=image,
                rag_query=None,
                rag_top_k=4,
                rag_use_keyword_llm=True,
                rag_keyword_max_items=5,
                system_instruction_template=system_instruction,
                system_instruction_variables={
                    "specialty": "tropical pulmonary diseases",
                    "audience": "clinicians",
                    "test_id": case_dir.name
                },
            )
        else:
            response = run_medgemma(
                prompt=user_prompt,
                prompt_template=prompt_template,
                prompt_variables=prompt_variables,
                image=image,
                system_instruction_template=system_instruction,
                system_instruction_variables={
                    "specialty": "tropical pulmonary diseases",
                    "audience": "clinicians",
                    "test_id": case_dir.name
                },
            )

        # Read ground truth
        ground_truth_path = case_dir / "ground_truth.txt"
        ground_truth = (
            ground_truth_path.read_text(encoding="utf-8").strip()
            if ground_truth_path.exists()
            else ""
        )

        # Store results
        result_data = {
            "case_id": case_dir.name,
            "predicted_disease": response.get("predicted"),
            "model_response":response.get("model_response"),
            "answer": response.get("answer"),
            #"latency": response.get("latency"),
            "ground_truth": ground_truth,
            #"resolved_prompt": response.get("resolved_prompt"),
            #"resolved_system_instruction": response.get("resolved_system_instruction"),
        }

        # Add RAG-specific fields if using RAG
        if use_rag:
            result_data.update({
                # "rag_keywords": response.get("rag_keywords", []),
                # "rag_query_used": response.get("rag_query_used"),
                "citations": response.get("citations", []),
                # "context_length": len(response.get("context", "")),
            })

        results.append(result_data)
        case_counter += 1

    print(f"\nProcessed {case_counter} cases.")
    return results

## Main execution
#medgemma without RAG
# print("=== Testing without RAG ===")
# testcase_results_no_rag = run_diagnosis_testcase(use_rag=False)
# pretty_print_result(testcase_results_no_rag)

# medgemma with RAG (if RAG system is available)
print("\n=== Testing with RAG ===")
testcase_results_rag = run_diagnosis_testcase(use_rag=True)
pretty_print_result(testcase_results_rag)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda
# === Testing with RAG ===
# Scanning for cases in: /content/drive/MyDrive/Data/Test-Data/extracted-data
# Using RAG: True
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processed 33 cases.
#
# ==================================================
# Case ID: 001
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# Context: ## Case 51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T (score=0.022)
# **Patient Information**: A 34-year-old Malawian woman diagnosed with smear-positive pulmonary tuberculosis and HIV 5 months prior to presentation. At that time, her baseline CD4 count was 54/µL. She is currently taking antituberculous therapy, vitamin B6, antiretroviral therapy, and co-trimoxazole prophylaxis.
# **Chief Complaint**: Slowly progressive weakness of the left arm and leg over a 3-month period.
# **History Of Present Illness**: The patient's problems began approximately 3 months earlier with a limp in her left leg. The weakness progressed insidiously, and over the following weeks, her left arm also became affected. She is noted to be a poor historian. She denies any head trauma, headache, recent episodes of fever, nausea, visual impairment, or loss of weight. The review of systems is unremarkable.
# **Exposure And Epidemiology**: The patient lives in an urban high-density area in Malawi and works as a street vendor. She is divorced and has no children. No specific exposures to animals, water, or sick contacts are mentioned.
# **Vitals**: The patient is afebrile and her vital signs are reported as normal.
# **Physical Exam**: General examination is normal except for slightly pale conjunctivae. Fundoscopy is normal with no signs of papilloedema or retinitis. Neurological examination reveals a spastic hemiparesis on the left with hyperreflexia. Power is 2/5 in the left leg and 3/5 in the left arm, with a pronator drift on the left. Sensation of pain is reduced in her left leg and hand. The examination of her cranial nerves is normal.
# **Labs And Diagnostics**: A full blood count showed a WBC of 3.8 x 10⁹/L, haemoglobin of 9.9 g/dL, and platelets of 140 x 10⁹/L. Routine CSF examination was normal, and India Ink stain with fungal cultures were negative. A cerebral MRI performed after 8 weeks of symptoms showed multifocal T2 hyperintense lesions exclusively affecting the white matter, more prominent in the right hemisphere, and a small area of demyelination in the left cerebellar peduncle. These radiological findings were deemed strongly suggestive of PML.
# **Differential Diagnosis**: The differential diagnosis for focal brain lesions in this HIV-positive patient included cerebral toxoplasmosis, progressive multifocal leukoencephalopathy (PML), CNS lymphoma, cryptococcoma, and CNS tuberculosis. The onset of symptoms two months after starting ART raised the possibility of Immune Reconstitution Inflammatory Syndrome (IRIS), potentially unmasking a pre-existing infection. Ischemic or hemorrhagic strokes were considered unlikely due to the slow, progressive nature of the illness.
# **Management And Clinical Course**: The patient's existing antiretroviral, antituberculous, and co-trimoxazole therapies were continued. She was started on empirical high-dose co-trimoxazole for presumed toxoplasmosis and prednisolone 1 mg/kg for possible IRIS. At 4-week follow-up, her condition was unchanged, and by 8 weeks, her left-sided weakness had deteriorated further. Following the MRI results, a presumed diagnosis of PML was made, and she was referred to a rehabilitation centre and a palliative care team.
# **Final Diagnosis**: A presumed diagnosis of Progressive Multifocal Leukoencephalopathy (PML) was made, likely occurring as an Immune Reconstitution Inflammatory Syndrome (PML-IRIS). The diagnosis was based on the clinical picture of slowly progressive focal neurological deficits in a patient with advanced HIV (CD4 54/µL) that began two months after initiating antiretroviral therapy. The diagnosis was strongly supported by characteristic MRI findings of multifocal, non-enhancing white matter lesions and the lack of clinical response to empirical treatment for other opportunistic infections like toxoplasmosis.
# **Disease Name Short**: Progressive Multifocal Leukoencephalopathy
#
# ## Case 91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic (score=0.021)
# **Patient Information**: A previously healthy 20-year-old man from southern India. He had a history of a dog bite one month prior to symptom onset, for which he received five doses of purified chick embryo cell anti-rabies vaccine but no rabies immunoglobulin (RIG).
# **Chief Complaint**: Admission to hospital for fever and quadriparesis.
# **History Of Present Illness**: The patient experienced fever for four days, which was followed by tingling and weakness that began in his left leg. The weakness subsequently progressed to involve all four limbs over the next two days, resulting in a rapidly progressive quadriparesis.
# **Exposure And Epidemiology**: The patient, from southern India (a rabies-endemic country), reported a history of a stray dog bite (WHO category III) on his left lower limb one month before his symptoms began. He received a full course of five anti-rabies vaccine doses but did not receive rabies immunoglobulin (RIG) as part of his post-exposure prophylaxis.
# **Vitals**: On admission, his blood pressure was 110/70 mmHg, pulse was 90 beats per minute, respiratory rate was 26 breaths per minute, and his temperature was 38.5°C (101.3°F).
# **Physical Exam**: On admission, the patient was conscious with normal mental functions (GCS 15/15). The neurological examination revealed a flaccid, areflexic quadriparesis.
# **Labs And Diagnostics**: Blood investigations, including serum electrolytes, renal function, and liver function tests, were normal. Cerebrospinal fluid (CSF) analysis showed a protein level of 52 mg/dL, glucose of 60 mg/dL, and a pleocytosis of 340 cells/mm³ (60% polymorphs and 40% lymphocytes). A saliva sample collected at admission was positive for rabies viral RNA by RT-PCR, while a CSF sample was negative for the virus.
# **Differential Diagnosis**: A high clinical suspicion of paralytic rabies was maintained due to the dog bite history and presentation. Clinical mimics considered included Guillain-Barré Syndrome (GBS) and post-vaccination encephalomyelitis. However, features such as fever at onset, paraesthesia in the bitten limb, rapid progression, and significant CSF pleocytosis helped differentiate this case from GBS.
# **Management And Clinical Course**: After admission, the patient's condition worsened, developing autonomic instability with increased perspiration and variable heart rate and blood pressure. He progressed to dysphagia and respiratory distress, requiring mechanical ventilation on the third day of hospitalization. His management was supportive. The patient died from a sudden cardiac arrest on the fifth day of hospitalization, which was nine days after the onset of his symptoms.
# **Final Diagnosis**: The final diagnosis is paralytic rabies. This is based on the classic history of a WHO category III dog bite one month prior in a rabies-endemic area, followed by a clinical presentation of fever and rapidly progressive, ascending flaccid paralysis. The diagnosis was confirmed by the detection of rabies viral RNA by RT-PCR in a saliva sample. The failure to administer rabies immunoglobulin (RIG) after the severe exposure was a critical lapse in post-exposure prophylaxis, which likely led to the development of the fatal disease despite vaccination.
# **Disease Name Short**: Paralytic rabies
#
# ## Case 56---A-21-Year-Old-Pregnant-Woman-from-The-Ga_2022_Clinical-Cases-in-Tropica (score=0.020)
# **Patient Information**: A 21-year-old woman, 32 weeks pregnant with her first pregnancy. She is from The Gambia and is reported to be otherwise well with no significant past medical history.
# **Chief Complaint**: A generalized, non-itchy rash for 5 days.
# **History Of Present Illness**: The patient presented with a 5-day history of a generalized, non-itchy rash. She reported being otherwise well and denied any other symptoms.
# **Exposure And Epidemiology**: The patient is from The Gambia. No other specific epidemiological risk factors such as travel, contacts, or other exposures were mentioned.
# **Vitals**: None
# **Physical Exam**: Physical examination revealed a generalized, non-itchy macular rash which involved the palms of both hands. The mouth was normal, and there was no lymphadenopathy. The patient was not anaemic or jaundiced, and the remainder of the general examination was unremarkable.
# **Labs And Diagnostics**: No laboratory or diagnostic test results, such as serological tests for syphilis, were reported for this patient. The diagnosis was based on clinical findings.
# **Differential Diagnosis**: The primary and most likely diagnosis presented is syphilis. The case discussion states that a generalized, non-itchy rash affecting the palms of the hands is considered 'syphilis until proven otherwise'. No other alternative diagnoses were discussed.
# **Management And Clinical Course**: The patient was treated with a single intramuscular (IM) dose of benzathine penicillin. Following this treatment, she made an uneventful recovery. She subsequently delivered a normal infant at term. The case notes that her infant should receive a course of treatment for congenital syphilis because maternal treatment was administered after 28 weeks' gestation.
# **Final Diagnosis**: The final diagnosis is secondary syphilis. This was a clinical diagnosis based on the classic presentation of a generalized, non-itchy macular rash involving the palms in a pregnant woman. The diagnosis was supported by the patient's complete and uneventful recovery after receiving a single dose of benzathine penicillin, the standard treatment for syphilis, and the subsequent delivery of a normal infant at term.
# **Disease Name Short**: Secondary syphilis
#
# ## Case 91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic (score=0.019)
# **Patient Information**: A previously healthy 20-year-old man from southern India. He had a history of a dog bite one month prior to symptom onset, for which he received five doses of purified chick embryo cell anti-rabies vaccine but no rabies immunoglobulin (RIG).
# **Chief Complaint**: Admission to hospital for fever and quadriparesis.
# **History Of Present Illness**: The patient experienced fever for four days, which was followed by tingling and weakness that began in his left leg. The weakness subsequently progressed to involve all four limbs over the next two days, resulting in a rapidly progressive quadriparesis.
# **Exposure And Epidemiology**: The patient, from southern India (a rabies-endemic country), reported a history of a stray dog bite (WHO category III) on his left lower limb one month before his symptoms began. He received a full course of five anti-rabies vaccine doses but did not receive rabies immunoglobulin (RIG) as part of his post-exposure prophylaxis.
# **Vitals**: On admission, his blood pressure was 110/70 mmHg, pulse was 90 beats per minute, respiratory rate was 26 breaths per minute, and his temperature was 38.5°C (101.3°F).
# **Physical Exam**: On admission, the patient was conscious with normal mental functions (GCS 15/15). The neurological examination revealed a flaccid, areflexic quadriparesis.
# **Labs And Diagnostics**: Blood investigations, including serum electrolytes, renal function, and liver function tests, were normal. Cerebrospinal fluid (CSF) analysis showed a protein level of 52 mg/dL, glucose of 60 mg/dL, and a pleocytosis of 340 cells/mm³ (60% polymorphs and 40% lymphocytes). A saliva sample collected at admission was positive for rabies viral RNA by RT-PCR, while a CSF sample was negative for the virus.
# **Differential Diagnosis**: A high clinical suspicion of paralytic rabies was maintained due to the dog bite history and presentation. Clinical mimics considered included Guillain-Barré Syndrome (GBS) and post-vaccination encephalomyelitis. However, features such as fever at onset, paraesthesia in the bitten limb, rapid progression, and significant CSF pleocytosis helped differentiate this case from GBS.
# **Management And Clinical Course**: After admission, the patient's condition worsened, developing autonomic instability with increased perspiration and variable heart rate and blood pressure. He progressed to dysphagia and respiratory distress, requiring mechanical ventilation on the third day of hospitalization. His management was supportive. The patient died from a sudden cardiac arrest on the fifth day of hospitalization, which was nine days after the onset of his symptoms.
# **Final Diagnosis**: The final diagnosis is paralytic rabies. This is based on the classic history of a WHO category III dog bite one month prior in a rabies-endemic area, followed by a clinical presentation of fever and rapidly progressive, ascending flaccid paralysis. The diagnosis was confirmed by the detection of rabies viral RNA by RT-PCR in a saliva sample. The failure to administer rabies immunoglobulin (RIG) after the severe exposure was a critical lapse in post-exposure prophylaxis, which likely led to the development of the fatal disease despite vaccination.
# **Disease Name Short**: Paralytic rabies
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 53-year-old woman presented with fever, cough, and malaise after returning from a visit to Lahore. On examination, her temperature was 38°C and she had a rash on her upper chest. A chest X-ray showed patchy basal consolidation and a full blood count revealed a relative lymphocytosis. Malaria films were negative. Blood cultures were drawn and later grew gram-negative bacilli.
# Patient age: 53
# Primary symptoms: List of symptoms of fever, cough, malaise
#
# Assistant:
# **Predicted disease:** Tuberculosis
# **Reason:** The patient's symptoms (fever, cough, malaise), chest X-ray findings (patchy basal consolidation), and the presence of gram-negative bacilli in the blood culture strongly suggest tuberculosis. While the travel history to Lahore is relevant, it doesn't definitively point to a specific tropical disease. The negative malaria film rules out malaria.
#
# Citations:
# [1] {'case_id': '51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T.json', 'chunk_id': '0005', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T.pdf'}
# [2] {'case_id': '91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic.json', 'chunk_id': '0013', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic.pdf'}
# [3] {'case_id': '56---A-21-Year-Old-Pregnant-Woman-from-The-Ga_2022_Clinical-Cases-in-Tropica', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/56---A-21-Year-Old-Pregnant-Woman-from-The-Ga_2022_Clinical-Cases-in-Tropica.json', 'chunk_id': '0005', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/56---A-21-Year-Old-Pregnant-Woman-from-The-Ga_2022_Clinical-Cases-in-Tropica.pdf'}
# [4] {'case_id': '91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic.json', 'chunk_id': '0008', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic.pdf'}
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 002
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# Context: ## Case 48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi (score=0.035)
# **Patient Information**: A 31-year-old woman from northern Tanzania. She has a history of a febrile illness 3 weeks prior to presentation, which was treated as malaria. She is married with 3 children, with the last born 12 months ago. She does not smoke or consume alcohol. Her HIV status during her last pregnancy was negative, and there is no past or family history of similar illness.
# **Chief Complaint**: Loss of power and feeling in her legs, with onset two days prior to referral.
# **History Of Present Illness**: The patient was well until two days before presentation, when she experienced acute, severe, continuous, burning back pain that radiated band-like to the level of her umbilicus. Within 12 hours, the pain lessened, but she developed ascending numbness in her feet and legs up to her waist, along with loss of power in her legs and loss of bladder control. This presentation was preceded by a febrile illness 3 weeks earlier.
# **Exposure And Epidemiology**: The patient resides in northern Tanzania. She had a febrile illness 3 weeks prior that was treated as malaria. There is no reported history of trauma.
# **Vitals**: Vital signs were reported as normal.
# **Physical Exam**: General examination was unremarkable, with no spinal tenderness, deformity, or gibbus. On neurological exam, she was fully oriented with normal higher mental functions, cranial nerves, and upper limbs. The lower limbs showed a flaccid paraparesis with a sensory level at T10. Tone was reduced bilaterally, power was MRC grade 1/5 in all muscle groups, and reflexes were absent bilaterally. Plantar reflexes were extensor. Sensation was reduced to light touch up to the umbilicus, with impaired joint position sense in the feet and ankles, and absent vibration sense up to the anterior iliac crest bilaterally.
# **Labs And Diagnostics**: Full blood count, renal, and liver function tests were normal. The ESR was 19 mm/h. HIV serology (and p24 antigen), VDRL, and schistosomiasis serology were all negative. Urine and stool tests for Schistosoma ova were also negative. A lumbar puncture revealed clear cerebrospinal fluid (CSF) with a normal opening pressure. CSF analysis showed a white cell count of 11 cells/µl (90% lymphocytes), an elevated protein of 1.11 g/L, and a normal glucose of 3.9 mmol/l. CSF Gram stain, Ziehl-Neelsen stain, Xpert MTB/RIF, and VDRL were all negative. X-rays of the chest and thoracolumbar spine were normal.
# **Differential Diagnosis**: The main differential diagnoses included lesions of peripheral nerves (polyneuropathies or polyradiculoneuropathies) and acute lesions of the spinal cord (myelopathies). The sensory impairment up to the T10 level and extensor plantar reflexes localized the lesion to the spinal cord. Among myelopathies, the key differentials were acute spinal cord inflammation (transverse myelitis) and vascular spinal cord ischemia. The CSF findings of increased lymphocytes and elevated protein were suggestive of inflammation, favoring acute transverse myelitis.
# **Management And Clinical Course**: The patient was treated with corticosteroids and acyclovir. She received supportive care including urinary catheterization and physiotherapy. After 3 weeks, she showed partial improvement, with leg power increasing to MRC grade 2-3/5. She was discharged with a urinary catheter in situ for outpatient review.
# **Final Diagnosis**: The final diagnosis is acute transverse myelitis. This is based on the clinical presentation of acute-onset flaccid paraplegia with a distinct T10 sensory level and bladder dysfunction, which localizes the lesion to the spinal cord. The diagnosis is further supported by cerebrospinal fluid analysis showing lymphocytic pleocytosis and elevated protein, indicating inflammation. Compressive lesions were ruled out by normal spinal X-rays, and specific infectious etiologies like syphilis, schistosomiasis, and tuberculosis were excluded by negative tests, making this a case of non-compressive myelitis, likely parainfectious given the preceding febrile illness.
# **Disease Name Short**: Acute transverse myelitis
#
# ## Case 48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi (score=0.028)
# **Patient Information**: A 31-year-old woman from northern Tanzania. She has a history of a febrile illness 3 weeks prior to presentation, which was treated as malaria. She is married with 3 children, with the last born 12 months ago. She does not smoke or consume alcohol. Her HIV status during her last pregnancy was negative, and there is no past or family history of similar illness.
# **Chief Complaint**: Loss of power and feeling in her legs, with onset two days prior to referral.
# **History Of Present Illness**: The patient was well until two days before presentation, when she experienced acute, severe, continuous, burning back pain that radiated band-like to the level of her umbilicus. Within 12 hours, the pain lessened, but she developed ascending numbness in her feet and legs up to her waist, along with loss of power in her legs and loss of bladder control. This presentation was preceded by a febrile illness 3 weeks earlier.
# **Exposure And Epidemiology**: The patient resides in northern Tanzania. She had a febrile illness 3 weeks prior that was treated as malaria. There is no reported history of trauma.
# **Vitals**: Vital signs were reported as normal.
# **Physical Exam**: General examination was unremarkable, with no spinal tenderness, deformity, or gibbus. On neurological exam, she was fully oriented with normal higher mental functions, cranial nerves, and upper limbs. The lower limbs showed a flaccid paraparesis with a sensory level at T10. Tone was reduced bilaterally, power was MRC grade 1/5 in all muscle groups, and reflexes were absent bilaterally. Plantar reflexes were extensor. Sensation was reduced to light touch up to the umbilicus, with impaired joint position sense in the feet and ankles, and absent vibration sense up to the anterior iliac crest bilaterally.
# **Labs And Diagnostics**: Full blood count, renal, and liver function tests were normal. The ESR was 19 mm/h. HIV serology (and p24 antigen), VDRL, and schistosomiasis serology were all negative. Urine and stool tests for Schistosoma ova were also negative. A lumbar puncture revealed clear cerebrospinal fluid (CSF) with a normal opening pressure. CSF analysis showed a white cell count of 11 cells/µl (90% lymphocytes), an elevated protein of 1.11 g/L, and a normal glucose of 3.9 mmol/l. CSF Gram stain, Ziehl-Neelsen stain, Xpert MTB/RIF, and VDRL were all negative. X-rays of the chest and thoracolumbar spine were normal.
# **Differential Diagnosis**: The main differential diagnoses included lesions of peripheral nerves (polyneuropathies or polyradiculoneuropathies) and acute lesions of the spinal cord (myelopathies). The sensory impairment up to the T10 level and extensor plantar reflexes localized the lesion to the spinal cord. Among myelopathies, the key differentials were acute spinal cord inflammation (transverse myelitis) and vascular spinal cord ischemia. The CSF findings of increased lymphocytes and elevated protein were suggestive of inflammation, favoring acute transverse myelitis.
# **Management And Clinical Course**: The patient was treated with corticosteroids and acyclovir. She received supportive care including urinary catheterization and physiotherapy. After 3 weeks, she showed partial improvement, with leg power increasing to MRC grade 2-3/5. She was discharged with a urinary catheter in situ for outpatient review.
# **Final Diagnosis**: The final diagnosis is acute transverse myelitis. This is based on the clinical presentation of acute-onset flaccid paraplegia with a distinct T10 sensory level and bladder dysfunction, which localizes the lesion to the spinal cord. The diagnosis is further supported by cerebrospinal fluid analysis showing lymphocytic pleocytosis and elevated protein, indicating inflammation. Compressive lesions were ruled out by normal spinal X-rays, and specific infectious etiologies like syphilis, schistosomiasis, and tuberculosis were excluded by negative tests, making this a case of non-compressive myelitis, likely parainfectious given the preceding febrile illness.
# **Disease Name Short**: Acute transverse myelitis
#
# ## Case 21---A-35-Year-Old-American-Man-With-Fatigue-_2022_Clinical-Cases-in-Tropica (score=0.028)
# **Patient Information**: A 35-year-old Caucasian male with an unremarkable past medical history. He works as a postal worker and has had no foreign travel within the previous year or contact with animals.
# **Chief Complaint**: Fatigue and a neck lesion that started as a papule two days prior.
# **History Of Present Illness**: The patient presented with a rash on his neck that began as a papule 2 days earlier. The lesion was non-pruritic but associated with significant non-painful swelling and a pressure sensation. He reported at least one episode of diaphoresis with mild confusion and headache but no fever. He recalled a break in the skin at the site of the lesion 3 days before its onset while shaving. He had been seen in a clinic 24 hours prior and was discharged on an oral cephalosporin, but returned due to worsening malaise, neck swelling, and mild difficulty breathing.
# **Exposure And Epidemiology**: The patient is a postal worker in the United States with no recent foreign travel, contact with animals, or known insect bites. The case occurred during an investigation into a bioterrorism event, and his exposure was later determined to be from handling contaminated mail during his occupation.
# **Vitals**: On examination, his temperature was 36.9°C (98.4°F), pulse was 118 bpm, blood pressure was 138/90 mmHg, and respiratory rate was 20 breaths per minute. His neck circumference had increased from a baseline of 57 cm to a peak of 81 cm.
# **Physical Exam**: Examination revealed a 2 cm irregularly shaped, indurated, non-tender patch on the left anterior neck with mild erythema and several 2 to 3 mm vesicles. The main lesion had a 6 mm shallow ulceration. There was massive neck oedema which made lymph node assessment difficult. The remainder of the physical examination was normal.
# **Labs And Diagnostics**: Initial laboratory investigations, including a full blood count, electrolytes, BUN, and creatinine, were normal except for a mildly elevated hemoglobin at 18.7 g/dL. Blood cultures taken at the first clinic visit grew gram-positive rods. A subsequent Gram stain and culture of the skin lesion were negative for B. anthracis. However, a skin biopsy sent to a reference laboratory showed abundant bacilli in the dermis, and immunohistochemical (IHC) staining confirmed the presence of B. anthracis antigens. Convalescent serology revealed the presence of antibodies to protective antigen.
# **Differential Diagnosis**: The differential diagnosis for an ulcerative skin lesion with massive swelling included bacterial ecthyma (Streptococcus pyogenes, Staphylococcus aureus), rickettsial diseases, necrotic arachnidism, rat-bite fevers, ulceroglandular tularemia, and bubonic plague. Given the ongoing bioterrorism investigation in the United States at the time, cutaneous anthrax was the most important diagnosis to consider, supported by the presence of a painless papule evolving into an ulcer with extensive, non-tender edema and systemic symptoms without significant fever.
# **Management And Clinical Course**: The patient was initially treated with a first-generation cephalosporin but his condition worsened. Upon his return to the clinic, he was admitted to the hospital and treated with intravenous levofloxacin and ampicillin-sulbactam. Following this treatment regimen, the patient recovered.
# **Final Diagnosis**: The final diagnosis is cutaneous anthrax caused by Bacillus anthracis. This was confirmed by immunohistochemical (IHC) staining of a skin biopsy which showed abundant B. anthracis antigens, and by serology showing antibodies to protective antigen in convalescent serum. The diagnosis is strongly supported by the patient's clinical picture of a painless ulcer with massive edema and his occupational exposure as a postal worker handling contaminated mail during a known bioterrorism event.
# **Disease Name Short**: Cutaneous anthrax
#
# ## Case 23---A-31-Year-Old-HIV-Positive-Business-Traveller-W_2022_Clinical-Cases-in- (score=0.025)
# **Patient Information**: A 31-year-old HIV-positive man, diagnosed 6 years prior, who is not on antiretroviral therapy (ART) or co-trimoxazole prophylaxis. His CD4 count one month before presentation was 280/μL, and on admission was 150/µL. He denies recreational drug use and has never smoked tobacco, with no other significant past medical history.
# **Chief Complaint**: A 6-week history of increasing shortness of breath, dry cough, and drenching night sweats.
# **History Of Present Illness**: The patient presented with a 6-week history of increasing shortness of breath on exertion, a dry cough, and drenching night sweats. He also reported general fatigue and a weight loss of about 10 kg over the past 5 months. At presentation, he was short of breath at rest but able to complete full sentences.
# **Exposure And Epidemiology**: The patient resides in London and travels extensively for business, with work trips in the past 6 months to Europe, China, Korea, Japan, Singapore, and the United States. He lives with his male partner. No other specific exposures were mentioned.
# **Vitals**: On admission, he was febrile with a temperature of 39.2°C (102.6°F), blood pressure of 120/70 mmHg, pulse of 100 bpm, and a respiratory rate of 26 breaths per minute. He was hypoxic with an oxygen saturation (sO2) of 87% on room air, which improved to 97% on 15L of O2.
# **Physical Exam**: The patient was alert but short of breath at rest. Auscultation of the chest was clear. The rest of the physical examination was unremarkable.
# **Labs And Diagnostics**: Arterial blood gas on ambient air showed respiratory failure with a PaO2 of 7.6 kPa. The full blood count, creatinine, urea, and liver function tests were normal. CRP was slightly elevated at 6.7 mg/dL. His CD4 count was 150/µL, and his HIV viral load was 1,500,000 copies/mL. A chest radiograph revealed bilateral perihilar infiltrates, and a chest CT showed extensive 'ground-glass' infiltrates with no pulmonary emboli. Serum β-D-glucan was >500 pg/mL. Bronchoalveolar lavage (BAL) fluid analysis confirmed the diagnosis, with Grocott staining revealing Pneumocystis jirovecii cystic forms and a strongly positive PCR for P. jirovecii DNA.
# **Differential Diagnosis**: Given the patient was ART-naïve and HIV-positive with a low CD4 count, progressive dyspnea, and bilateral infiltrates, Pneumocystis pneumonia (PCP) was the leading differential. Other possibilities considered included tuberculosis, atypical bacterial pneumonia, cryptococcosis, or histoplasmosis, particularly in light of his extensive travel. Pulmonary embolism was also considered due to recent long-haul flights but was ruled out by CT scan.
# **Management And Clinical Course**: The patient received high-flow oxygen, high-dose intravenous co-trimoxazole, and prednisolone. He commenced antiretroviral therapy (tenofovir, emtricitabine, efavirenz) ten days into treatment. Two weeks into his course, he developed a drug rash, which prompted a switch of PCP treatment to clindamycin and primaquine to complete a 21-day total course. His ART was also changed. His hypoxia resolved, and he was discharged on dapsone and pyrimethamine for secondary prophylaxis.
# **Final Diagnosis**: The final diagnosis is severe Pneumocystis pneumonia (PCP) due to the fungus *Pneumocystis jirovecii*. The diagnosis was made in an ART-naïve, HIV-positive man presenting with subacute respiratory failure, profound hypoxia, and a low CD4 count (150/µL). It was supported by classic 'ground-glass' infiltrates on chest CT and a highly elevated serum β-D-glucan level, and was definitively confirmed by finding *P. jirovecii* cystic forms on Grocott staining and positive PCR of bronchoalveolar lavage fluid.
# **Disease Name Short**: Pneumocystis pneumonia
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 26-year-old woman presents one week after returning from a trip to the Gambia. She reports an abrupt onset of shivering, feeling cold, rigors, vomiting, and profuse sweating, accompanied by headache and nausea. On examination, she is pale, has a temperature of 39.5°C, and is tachycardic. The patient reports having taken anti-malarial tablets during her trip but was admitted with a febrile illness.
# Patient age: 26
# Primary symptoms: Symptoms of shivering, vomiting, profuse sweating, accompanied by headache, nausea, accompanied by vomiting
#
# [Image provided]
#
# Assistant:
# **Predicted disease:** Malaria
# **Reason:** The patient's symptoms (shivering, fever, headache, nausea, vomiting, sweating) and travel history to the Gambia strongly suggest malaria. The microscopic image shows the characteristic morphology of Plasmodium parasites, confirming the diagnosis.
#
# Citations:
# [1] {'case_id': '48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi.json', 'chunk_id': '0009', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi.pdf'}
# [2] {'case_id': '48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi.json', 'chunk_id': '0003', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi.pdf'}
# [3] {'case_id': '21---A-35-Year-Old-American-Man-With-Fatigue-_2022_Clinical-Cases-in-Tropica', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/21---A-35-Year-Old-American-Man-With-Fatigue-_2022_Clinical-Cases-in-Tropica.json', 'chunk_id': '0009', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/21---A-35-Year-Old-American-Man-With-Fatigue-_2022_Clinical-Cases-in-Tropica.pdf'}
# [4] {'case_id': '23---A-31-Year-Old-HIV-Positive-Business-Traveller-W_2022_Clinical-Cases-in-', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/23---A-31-Year-Old-HIV-Positive-Business-Traveller-W_2022_Clinical-Cases-in-.json', 'chunk_id': '0008', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/23---A-31-Year-Old-HIV-Positive-Business-Traveller-W_2022_Clinical-Cases-in-.pdf'}
#
# Latency: 0.00s
#
# ==================================================
# Case ID: 003
# ==================================================
#
# Answer:
#  System:
# You are an expert in tropical pulmonary diseases communicating with clinicians. Read the clinical case and provide the single most likely diagnosis.
# ### Format your response as:
# **Predicted disease:**[Respond with most accurate diagnosis name]
# **Reason:**[Short explanation]
#
# Context: ## Case 16---A-25-Year-Old-Female-School-Teacher-from-Malaw_2022_Clinical-Cases-in-T (score=0.035)
# **Patient Information**: A 25-year-old Malawian primary school teacher who is HIV-positive and on first-line antiretroviral therapy (ART) with tenofovir, lamivudine and efavirenz for 6 months with good adherence. Her CD4 count upon starting ART was 320 cells/µL. She had completed treatment for pulmonary tuberculosis 2 months prior.
# **Chief Complaint**: Abrupt onset of high fever, confusion, and convulsions.
# **History Of Present Illness**: The patient was reported to be well at 8 a.m., but became confused by 10 a.m. and was then drowsy with a high fever and convulsions upon admission to a central hospital at 11 a.m., indicating a very rapid clinical deterioration over just a few hours.
# **Exposure And Epidemiology**: The patient is a primary school teacher residing in Malawi. The text notes that Streptococcus pneumoniae is the most common cause of meningitis in adults in Africa. There is no mention of specific travel, animal, or other environmental exposures.
# **Vitals**: On admission, her temperature was 40°C (104°F), pulse was 125 bpm, blood pressure was 125/68 mmHg, and oxygen saturation was 93% on room air.
# **Physical Exam**: The patient was restless and agitated with a Glasgow Coma Scale of 10/15. Physical examination revealed a stiff neck, a positive Kernig's sign, photophobia with equal and reactive pupils, and down-going plantar responses. No rash was present. Chest and abdominal examinations were unremarkable. During the physical examination, she suffered a renewed seizure.
# **Labs And Diagnostics**: Blood tests showed a white blood cell count of 10.5 x10^9/L (neutrophils 8.9 x10^9/L), haemoglobin of 8.9 g/dL, and normal platelets. A rapid antigen test for Plasmodium falciparum was negative. A lumbar puncture was performed, and the cerebrospinal fluid (CSF) appeared hazy. CSF analysis showed 35 leukocytes/µL (60% neutrophils), a high protein of 2.6 g/L, and a low glucose of 1.2 mmol/L. The CSF culture grew Streptococcus pneumoniae.
# **Differential Diagnosis**: The main differential diagnoses considered were acute bacterial meningitis, tuberculous meningitis (TBM), and cryptococcal meningitis (CCM). Acute bacterial meningitis was deemed most likely due to the hyperacute presentation. TBM was considered less likely due to the patient's recent completion of TB therapy and the rapid onset, while CCM was less likely because her CD4 count was too high and it typically presents more sub-acutely.
# **Management And Clinical Course**: In the emergency department, the patient received ceftriaxone 2g IV for the suspected meningitis, along with 10mg of diazepam IV and 600mg of phenobarbitone IV for seizure control. She completed a 10-day course of IV ceftriaxone. The patient recovered consciousness by day 3, and anticonvulsants were weaned. She developed a minor hearing loss in her right ear but had no other neurological impairment or seizures upon recovery.
# **Final Diagnosis**: The final diagnosis is acute bacterial meningitis caused by Streptococcus pneumoniae. This was definitively confirmed by a positive CSF culture. The diagnosis is strongly supported by the clinical triad of fever, altered consciousness, and signs of meningeal irritation (stiff neck, Kernig's sign), combined with classic CSF findings of a neutrophilic pleocytosis, elevated protein, and low glucose. Other causes like tuberculous and cryptococcal meningitis were clinically less likely.
# **Disease Name Short**: Acute Bacterial Meningitis
#
# ## Case 58---A-25-Year-Old-Woman-from-Egypt-With-Severe-Ch_2022_Clinical-Cases-in-Tr (score=0.031)
# **Patient Information**: A 25-year-old woman from Bani Suwaif in Upper Egypt. No pre-existing comorbidities were reported.
# **Chief Complaint**: Severe diarrhoea for 2 months accompanied by significant weight loss (15 kg) and amenorrhoea.
# **History Of Present Illness**: The patient's symptoms began two months prior with stomach rumbles and colicky abdominal pain, later progressing to anorexia and vomiting. She experienced voluminous diarrhoea, occurring five to ten times in 24 hours, both during the day and at night, and unrelated to meals. Over the last month, she developed lower limb swelling and severe prostration. She had received various antibiotics, including metronidazole, as well as antidiarrhoeal drugs without any improvement.
# **Exposure And Epidemiology**: The patient resides in Bani Suwaif, Upper Egypt, which is an endemic area for Capillaria philippinensis. The text notes that capillariasis is transmitted through the consumption of raw or undercooked fish, which is the likely source of her infection.
# **Vitals**: On presentation, the patient was afebrile, with a heart rate of 100 bpm and a blood pressure of 100/60 mmHg.
# **Physical Exam**: The patient appeared generally unwell, pale, and had angular stomatitis. Examination revealed a scaphoid abdomen with borborygmi, pitting oedema of the lower limbs, and decreased skin turgor.
# **Labs And Diagnostics**: Laboratory findings showed electrolyte derangements with hypokalaemia (2.8 mmol/L), hyponatraemia (127 mmol/L), hypocalcaemia (2.1 mmol/L), and severe hypoalbuminaemia (23 g/L). Additional results included mild anaemia (haemoglobin 10.8 g/dL), mild eosinophilia (0.53 x 10^9/L), and elevated creatinine (115 µmol/L). A D-xylose test showed evidence of malabsorption. The diagnosis was confirmed by stool microscopy, which detected numerous peanut-shaped helminth ova characteristic of Capillaria philippinensis.
# **Differential Diagnosis**: Given the chronic diarrhoea, initial considerations likely included other infectious causes, as suggested by the empiric but unsuccessful treatment with antibiotics like metronidazole. However, the definitive finding of helminth ova on stool microscopy established a parasitic etiology.
# **Management And Clinical Course**: The patient was admitted to the hospital and initiated on albendazole 400 mg twice daily for 3 weeks. She also received supportive care including oral and parenteral fluids and electrolytes for resuscitation, a high-protein diet, and vitamins. During the first days of treatment, numerous adult helminths were found in stool samples. Her general condition improved significantly within the first week, vomiting stopped, and the diarrhoea subsided after two weeks of treatment.
# **Final Diagnosis**: The diagnosis is intestinal capillariasis, a zoonotic disease caused by the nematode Capillaria philippinensis. This was confirmed by the microscopic identification of typical peanut-shaped ova in the patient's stool. The clinical presentation of severe chronic diarrhoea, weight loss, and signs of malabsorption (pitting oedema, hypoalbuminemia) in a patient from an endemic region is classic for this infection. The parasite's unique ability to multiply within the host via an autoinfection cycle explains the severe and long-lasting nature of the illness. The patient's positive response to albendazole therapy further supports the diagnosis.
# **Disease Name Short**: Intestinal capillariasis
#
# ## Case 8---A-26-Year-Old-Female-Traveller-Returning-from_2022_Clinical-Cases-in-Tro (score=0.031)
# **Patient Information**: A 26-year-old German student, described as otherwise fine, with no reported history of significant medical conditions.
# **Chief Complaint**: A localized, itchy swelling on the left leg that has been slowly developing over three weeks.
# **History Of Present Illness**: A 26-year-old female presents with a localized swelling on her left leg that developed slowly over the past 3 weeks. The lesion is reported to be itchy but not painful. She has no history of fever or recalled arthropod bites and feels well systemically.
# **Exposure And Epidemiology**: The patient had just returned from a 6-week backpacking trip to Ghana. In sub-Saharan Africa, myiasis is often caused by the Tumbu fly, which lays eggs on damp laundry or sandy ground. Humans can become hosts by wearing contaminated clothing that has not been hot-ironed or by lying on contaminated ground.
# **Vitals**: The patient was afebrile at the time of examination. No other vital signs were reported.
# **Physical Exam**: On the left leg, there was a localized swelling approximately 1.5 cm in diameter, covered by a blackish scab. The surrounding skin was slightly hyperaemic. There was no associated lymphadenopathy, and the rest of the physical examination was normal.
# **Labs And Diagnostics**: No laboratory or imaging studies were performed. Diagnosis was made clinically after the scab was removed, revealing a whitish, pulsating matter underneath that was oozing transparent fluid. Under a magnifying glass, this was identified as the pulsating end of a larva, containing respiratory spiracles, which is typical for myiasis.
# **Differential Diagnosis**: The primary differential diagnoses included rickettsial disease and cutaneous anthrax, which were deemed unlikely due to the absence of systemic symptoms. A spider bite was also considered but made less probable by the slow growth over weeks. Localized bacterial infections like furuncles were a possibility given the travel history, but the most likely diagnosis was myiasis (infestation with fly maggots) based on the slow growth, lack of systemic signs, and localized itch.
# **Management And Clinical Course**: The lesion was managed by occluding the larva's respiratory spiracles to deprive it of oxygen. The area was covered with white petroleum jelly and bandaged. The patient returned two days later, at which point the maggot of a Tumbu fly was easily removed with forceps. The remaining lesion appeared clean, and no further treatment was necessary. The condition is noted to be self-limiting as the mature larva eventually leaves the host.
# **Final Diagnosis**: The patient was diagnosed with cutaneous furuncular myiasis caused by the larva of the Tumbu fly, Cordylobia anthropophaga. The diagnosis was confirmed by the clinical presentation of a slowly growing, itchy boil in a traveler returning from Ghana, and definitively established by the direct visualization of the pulsating larva with its respiratory spiracles after removal of the scab, followed by its successful extraction. Alternative diagnoses like bacterial infection or spider bite were excluded based on the lesion's slow, non-painful evolution and the absence of systemic symptoms.
# **Disease Name Short**: Cutaneous myiasis
#
# ## Case 48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi (score=0.029)
# **Patient Information**: A 31-year-old woman from northern Tanzania. She has a history of a febrile illness 3 weeks prior to presentation, which was treated as malaria. She is married with 3 children, with the last born 12 months ago. She does not smoke or consume alcohol. Her HIV status during her last pregnancy was negative, and there is no past or family history of similar illness.
# **Chief Complaint**: Loss of power and feeling in her legs, with onset two days prior to referral.
# **History Of Present Illness**: The patient was well until two days before presentation, when she experienced acute, severe, continuous, burning back pain that radiated band-like to the level of her umbilicus. Within 12 hours, the pain lessened, but she developed ascending numbness in her feet and legs up to her waist, along with loss of power in her legs and loss of bladder control. This presentation was preceded by a febrile illness 3 weeks earlier.
# **Exposure And Epidemiology**: The patient resides in northern Tanzania. She had a febrile illness 3 weeks prior that was treated as malaria. There is no reported history of trauma.
# **Vitals**: Vital signs were reported as normal.
# ...
# **Management And Clinical Course**: The patient was treated with corticosteroids and acyclovir. She received supportive care including urinary catheterization and physiotherapy. After 3 weeks, she showed partial improvement, with leg power increasing to MRC grade 2-3/5. She was discharged with a urinary catheter in situ for outpatient review.
# **Final Diagnosis**: The final diagnosis is acute transverse myelitis. This is based on the clinical presentation of acute-onset flaccid paraplegia with a distinct T10 sensory level and bladder dysfunction, which localizes the lesion to the spinal cord. The diagnosis is further supported by cerebrospinal fluid analysis showing lymphocytic pleocytosis and elevated protein, indicating inflammation. Compressive lesions were ruled out by normal spinal X-rays, and specific infectious etiologies like syphilis, schistosomiasis, and tuberculosis were excluded by negative tests, making this a case of non-compressive myelitis, likely parainfectious given the preceding febrile illness.
# **Disease Name Short**: Acute transverse myelitis
#
# ## Case 91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic (score=0.024)
# **Patient Information**: A previously healthy 20-year-old man from southern India. He had a history of a dog bite one month prior to symptom onset, for which he received five doses of purified chick embryo cell anti-rabies vaccine but no rabies immunoglobulin (RIG).
# **Chief Complaint**: Admission to hospital for fever and quadriparesis.
# **History Of Present Illness**: The patient experienced fever for four days, which was followed by tingling and weakness that began in his left leg. The weakness subsequently progressed to involve all four limbs over the next two days, resulting in a rapidly progressive quadriparesis.
# **Exposure And Epidemiology**: The patient, from southern India (a rabies-endemic country), reported a history of a stray dog bite (WHO category III) on his left lower limb one month before his symptoms began. He received a full course of five anti-rabies vaccine doses but did not receive rabies immunoglobulin (RIG) as part of his post-exposure prophylaxis.
# **Vitals**: On admission, his blood pressure was 110/70 mmHg, pulse was 90 beats per minute, respiratory rate was 26 breaths per minute, and his temperature was 38.5°C (101.3°F).
# **Physical Exam**: On admission, the patient was conscious with normal mental functions (GCS 15/15). The neurological examination revealed a flaccid, areflexic quadriparesis.
# **Labs And Diagnostics**: Blood investigations, including serum electrolytes, renal function, and liver function tests, were normal. Cerebrospinal fluid (CSF) analysis showed a protein level of 52 mg/dL, glucose of 60 mg/dL, and a pleocytosis of 340 cells/mm³ (60% polymorphs and 40% lymphocytes). A saliva sample collected at admission was positive for rabies viral RNA by RT-PCR, while a CSF sample was negative for the virus.
# **Differential Diagnosis**: A high clinical suspicion of paralytic rabies was maintained due to the dog bite history and presentation. Clinical mimics considered included Guillain-Barré Syndrome (GBS) and post-vaccination encephalomyelitis. However, features such as fever at onset, paraesthesia in the bitten limb, rapid progression, and significant CSF pleocytosis helped differentiate this case from GBS.
# **Management And Clinical Course**: After admission, the patient's condition worsened, developing autonomic instability with increased perspiration and variable heart rate and blood pressure. He progressed to dysphagia and respiratory distress, requiring mechanical ventilation on the third day of hospitalization. His management was supportive. The patient died from a sudden cardiac arrest on the fifth day of hospitalization, which was nine days after the onset of his symptoms.
# **Final Diagnosis**: The final diagnosis is paralytic rabies. This is based on the classic history of a WHO category III dog bite one month prior in a rabies-endemic area, followed by a clinical presentation of fever and rapidly progressive, ascending flaccid paralysis. The diagnosis was confirmed by the detection of rabies viral RNA by RT-PCR in a saliva sample. The failure to administer rabies immunoglobulin (RIG) after the severe exposure was a critical lapse in post-exposure prophylaxis, which likely led to the development of the fatal disease despite vaccination.
# **Disease Name Short**: Paralytic rabies
#
# ## Case 11---A-45-Year-Old-Male-Security-Guard-from-Malawi-_2022_Clinical-Cases-in-T (score=0.018)
# **Patient Information**: A 45-year-old security guard from Malawi with no history of trauma or past tuberculosis. His HIV status was initially unknown but he was later found to be HIV-positive. He is a non-smoker but drinks about one litre of a locally brewed beer daily. He is married with three children who are all well.
# **Chief Complaint**: Back pain and progressive difficulty in walking.
# **History Of Present Illness**: The patient's troubles started one year prior with back pain, for which he was given paracetamol without improvement. Over the following weeks, he developed difficulty walking and 'pins and needles' sensations in his legs. His condition progressively deteriorated over the next six months until he became bedridden. He denies fever, night sweats, weight loss, or chronic cough, and reports no haematuria or diarrhoea, remaining continent for stool and urine.
# **Exposure And Epidemiology**: The patient resides in an urban area in Malawi where he worked as a security guard until he became unemployed due to his illness. He consulted a local traditional healer who applied tattoos to his chest and back. He has never been tested for HIV before this illness. No sick contacts were reported.
# **Vitals**: On a visit to a health center three months after symptom onset, his temperature was slightly elevated at 37.5°C (99.5°F). At the time of the main hospital admission and examination, he was afebrile with normal vital signs.
# **Physical Exam**: Examination revealed tenderness over the lower thoracic spine and severe spasticity of both legs, with visible contractures. Power in his legs was 1/5 (visible muscle flicker). Deep tendon reflexes of the lower limbs were exaggerated, and plantar reflexes were upgoing. A sensory level for pain and temperature was found between T9 and T11, with diminished joint sense in his big toes bilaterally. The examination of his cranial nerves and upper limbs was normal.
# **Labs And Diagnostics**: Full blood count results were normal. The patient tested positive for HIV with a CD4 count of 331 cells/µL. Urine dipstick was normal, and no ova of Schistosoma spp. were found in urine or stool. A spinal radiograph showed a collapse of the T11 vertebral body and associated soft tissue swelling around the spine. Chest radiography and abdominal ultrasound examinations were normal.
# **Differential Diagnosis**: The clinical signs of spastic paraparesis with a thoracic sensory level localize the lesion to the spinal cord. Differential diagnoses for non-traumatic compressive spinal cord disease in this setting include spinal tuberculosis (Pott’s disease), spinal metastases, and degenerative spinal disease. Non-compressive causes considered were schistosomiasis, autoimmune transverse myelitis, and HIV-associated vacuolar myelopathy.
# **Management And Clinical Course**: A presumed diagnosis of spinal TB was made, and the patient was started on standard first-line antituberculous treatment, along with vitamin B6. Physiotherapy and intensive guardian counseling were initiated. A spinal surgeon did not recommend surgical intervention at the time. The patient was discharged home with involvement from the palliative care team. At 4 weeks, he was started on antiretroviral therapy. By the 3-month follow-up, his neurological deficits remained clinically unchanged, though he reported some subjective improvement in his gait. He missed his neurosurgical follow-up appointment due to transportation issues.
# **Final Diagnosis**: The final diagnosis is presumed spinal tuberculosis (Pott's disease) with compressive myelopathy. This is based on the clinical syndrome of chronic progressive spastic paraparesis, the patient's HIV-positive status, and characteristic radiological findings of a T11 vertebral body collapse with a paravertebral soft tissue mass. Other relevant tropical etiologies like schistosomiasis were ruled out by negative laboratory tests. The diagnosis was further supported by the decision to commence antituberculous therapy.
# **Disease Name Short**: Spinal tuberculosis (Pott's disease)
#
# ## Case 51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T (score=0.018)
# **Patient Information**: A 34-year-old Malawian woman diagnosed with smear-positive pulmonary tuberculosis and HIV 5 months prior to presentation. At that time, her baseline CD4 count was 54/µL. She is currently taking antituberculous therapy, vitamin B6, antiretroviral therapy, and co-trimoxazole prophylaxis.
# **Chief Complaint**: Slowly progressive weakness of the left arm and leg over a 3-month period.
# **History Of Present Illness**: The patient's problems began approximately 3 months earlier with a limp in her left leg. The weakness progressed insidiously, and over the following weeks, her left arm also became affected. She is noted to be a poor historian. She denies any head trauma, headache, recent episodes of fever, nausea, visual impairment, or loss of weight. The review of systems is unremarkable.
# **Exposure And Epidemiology**: The patient lives in an urban high-density area in Malawi and works as a street vendor. She is divorced and has no children. No specific exposures to animals, water, or sick contacts are mentioned.
# **Vitals**: The patient is afebrile and her vital signs are reported as normal.
# **Physical Exam**: General examination is normal except for slightly pale conjunctivae. Fundoscopy is normal with no signs of papilloedema or retinitis. Neurological examination reveals a spastic hemiparesis on the left with hyperreflexia. Power is 2/5 in the left leg and 3/5 in the left arm, with a pronator drift on the left. Sensation of pain is reduced in her left leg and hand. The examination of her cranial nerves is normal.
# **Labs And Diagnostics**: A full blood count showed a WBC of 3.8 x 10⁹/L, haemoglobin of 9.9 g/dL, and platelets of 140 x 10⁹/L. Routine CSF examination was normal, and India Ink stain with fungal cultures were negative. A cerebral MRI performed after 8 weeks of symptoms showed multifocal T2 hyperintense lesions exclusively affecting the white matter, more prominent in the right hemisphere, and a small area of demyelination in the left cerebellar peduncle. These radiological findings were deemed strongly suggestive of PML.
# **Differential Diagnosis**: The differential diagnosis for focal brain lesions in this HIV-positive patient included cerebral toxoplasmosis, progressive multifocal leukoencephalopathy (PML), CNS lymphoma, cryptococcoma, and CNS tuberculosis. The onset of symptoms two months after starting ART raised the possibility of Immune Reconstitution Inflammatory Syndrome (IRIS), potentially unmasking a pre-existing infection. Ischemic or hemorrhagic strokes were considered unlikely due to the slow, progressive nature of the illness.
# **Management And Clinical Course**: The patient's existing antiretroviral, antituberculous, and co-trimoxazole therapies were continued. She was started on empirical high-dose co-trimoxazole for presumed toxoplasmosis and prednisolone 1 mg/kg for possible IRIS. At 4-week follow-up, her condition was unchanged, and by 8 weeks, her left-sided weakness had deteriorated further. Following the MRI results, a presumed diagnosis of PML was made, and she was referred to a rehabilitation centre and a palliative care team.
# **Final Diagnosis**: A presumed diagnosis of Progressive Multifocal Leukoencephalopathy (PML) was made, likely occurring as an Immune Reconstitution Inflammatory Syndrome (PML-IRIS). The diagnosis was based on the clinical picture of slowly progressive focal neurological deficits in a patient with advanced HIV (CD4 54/µL) that began two months after initiating antiretroviral therapy. The diagnosis was strongly supported by characteristic MRI findings of multifocal, non-enhancing white matter lesions and the lack of clinical response to empirical treatment for other opportunistic infections like toxoplasmosis.
# **Disease Name Short**: Progressive Multifocal Leukoencephalopathy
#
# User:
# You are diagnosing tropical diseases for a patient:
# Question: A 38-year-old man presented with a one-week history of high-grade intermittent fever, rigors, chills, headache, retro-orbital pain, and myalgia. For the past two days, he has also experienced reddish-colored urine with clots and two episodes of gum bleeding. On physical examination, his vital signs were stable, but he had multiple purpura and petechiae on his shoulder, trunk, and legs, as well as large ecchymotic lesions on his back. Laboratory studies revealed a very low platelet count of 20,000/μL and a low white blood cell count of 2.4 x 10^9/L. A tourniquet test was also positive.
# Patient age: 38
# Primary symptoms: Symptoms of intermittent fever, rigors, chills, headache, retro-orbital pain, myalgia
#
# [Image provided]
#
# Assistant:
# **Predicted disease:** Dengue Hemorrhagic Fever (DHF)
#
# **Reason:** The patient's presentation with high-grade fever, headache, retro-orbital pain, myalgia, purpura, petechiae, ecchymotic lesions, thrombocytopenia (low platelet count), and a positive tourniquet test strongly suggests Dengue Hemorrhagic Fever (DHF). The reddish-colored urine with clots and gum bleeding further support this diagnosis, indicating bleeding complications associated with DHF.
#
# Citations:
# [1] {'case_id': '48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi.json', 'chunk_id': '0009', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/48---A-31-Year-Old-Woman-from-Tanzania-With-Acu_2022_Clinical-Cases-in-Tropi.pdf'}
# [2] {'case_id': '91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic.json', 'chunk_id': '0013', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/91---A-20-Year-Old-Male-from-India-With-Fever-_2022_Clinical-Cases-in-Tropic.pdf'}
# [3] {'case_id': '11---A-45-Year-Old-Male-Security-Guard-from-Malawi-_2022_Clinical-Cases-in-T', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/11---A-45-Year-Old-Male-Security-Guard-from-Malawi-_2022_Clinical-Cases-in-T.json', 'chunk_id': '0008', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/11---A-45-Year-Old-Male-Security-Guard-from-Malawi-_2022_Clinical-Cases-in-T.pdf'}
# [4] {'case_id': '51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T', 'meta_ref': '/content/drive/MyDrive/Project-AI/structured-data-json/51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T.json', 'chunk_id': '0005', 'source_pdf': 'https:///content/drive/MyDrive/Project-AI/Data/pdf-data/51---A-34-Year-Old-HIV-Positive-Woman-from-Malawi-W_2022_Clinical-Cases-in-T.pdf'}
#
# Latency: 0.00s

# %%
# SAVE TO EXCEL
import pandas as pd
# df1 = pd.DataFrame(testcase_results_no_rag)
# output_path_1 = "/content/testcase_medgemma_without_rag.xlsx"
# df1.to_excel(output_path_1, index=False)
# print(f"\nExcel saved to: {output_path_1}")

df2 = pd.DataFrame(testcase_results_rag)
output_path_2 = "/content/testcase_medgemma_with_rag.xlsx"
df2.to_excel(output_path_2, index=False)
print(f"\nExcel saved to: {output_path_2}")
# Out:
# Excel saved to: /content/testcase_medgemma_with_rag.xlsx

# %% [markdown]
# #Reset Memory

# %%
del pipe
torch.cuda.empty_cache()

# %%
import gc
gc.collect()
# Out:
# 254

# %%
import torch
torch.cuda.empty_cache()

# %%
import pkg_resources
import google.protobuf
import transformers
import torch

print("qdrant-client:", pkg_resources.get_distribution("qdrant-client").version)
print("protobuf:", google.protobuf.__version__)
print("transformers:", transformers.__version__)
print("torch:", torch.__version__)
# Out:
# qdrant-client: 1.16.0
# protobuf: 5.29.5
# transformers: 4.57.1
# torch: 2.8.0+cu126
